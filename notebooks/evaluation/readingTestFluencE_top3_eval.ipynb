# %%
from src.data_processing import *
from src.wav2vec2_french_phonemizer import *
from src.readingTestFluencE_eval import *
from src.readingTestFluencE_eval_with_proba import *

# %%
# We prepare the test data for the readingTestFluencE dataset
readingTestFluencE_df = prepare_readingTestFluencE_data()
# Out:
# /Users/cleo/EPFL/Ma2/Project/Rhythmico-ASR/src/data_processing.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   readingTestFluencE_df['testResults'] = readingTestFluencE_df['testResults'].apply(lambda x: convert_str_to_dct_eval(x))
# /Users/cleo/EPFL/Ma2/Project/Rhythmico-ASR/src/data_processing.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   readingTestFluencE_df['evaluationResults'] = readingTestFluencE_df['evaluationResults'].apply(lambda x: convert_str_to_dct_eval(x))

# %%
# The tests id of the 10 selected readingTestFluencE tests
tests_id = [
    '2BB671AA-2F6A-4346-8B76-F0C89C236390',
    '3B545E56-D802-4380-9993-21C11066B12E',
    '5C1C826F-E778-48C3-9170-6BF943175984',
    '046E4FEB-E284-48D5-922E-616DA7651F02',
    '75A80925-F8CF-463D-AFED-5CC399848CC2',
    '102DCD09-43EA-434D-A590-0FA5C7C7C1B3',
    '098522E8-2203-425E-85E5-5809D5B0B523',
    '79055215-1979-42D3-9B26-B9C6DD935D83',
    'ABD81BE7-7629-4816-8241-7ECBF32DFFFA',
]

# %%
# We generate the top-3 phoneme transcriptions for the selected tests
top_3_phoneme_transcriptions(tests_id=tests_id)

# %%
# The full text of the readingTestFluencE
ground_truth = 'sɛ listwaʁ də møsjø pəti ki vi dɑ˜z yn vjɛj mɛzɔ˜ sitye o kœʁ dœ˜ vjø vilaʒ la mɛzɔ˜ ɛt ɑ˜tuʁe dœ˜ ʒaʁdɛ˜ avɛk yn baʁjɛʁ il i a de kɔ˜kɔ˜bʁ de ʃu fʁize tut sɔʁt də leɡymz o fɔ˜ dy ʒaʁdɛ˜ lə pɔʁtijɔ˜ ʁɛst tuʒuʁ fɛʁme puʁ kə ʃjɛ˜ a pys nə seʃap pa ʃjɛ˜ a pysz ɛm sə kuʃe pʁɛ də la pubɛl a lɔ˜bʁ dœ˜n ɔʁɑ˜ʒe kuvɛʁ də fʁyi delisjø ʃjɛ˜ a pysz ɛ ɡuʁmɑ˜ il kʁɔk tu sə ki lyi pas su la dɑ˜ dez ɔʁɑ˜ʒ puʁi ki tɔ˜b syʁ lə sɔl de flœʁ fanez œ˜ mɔʁso də byvaʁ œ˜ ʒuʁ məsjø pəti desid də mɛtʁ ʃjɛ̃ a pys dɑ˜z yn niʃ ʃjɛ˜ a pys nɛm paz ɛtʁ ɑ˜fɛʁme il pʁefɛʁ sɑ˜dɔʁmiʁ ɑ˜ ʁəɡaʁdɑ˜ lez etwal dɑ˜ lə sjɛl tut le nyiz il abwa kɑ˜ məsjø pəti va sə kuʃe məsjø pəti desid də dɔʁmiʁ dɑ˜ lə ɡʁənje də sa ʒɔli mɛzɔ˜ puʁ pʁɑ˜dʁ œ˜ pø də ʁəpoz il nə tʁuv ply lə sɔmɛj yn nyi dɛ˜sɔmni ɔp il sot dy li e uvʁ la ɡʁɑ˜d mal ki sə tʁuv dəvɑ˜ lyi dɑ˜z œ˜ kwɛ˜ sɔ˜bʁ dy ɡʁənje e la syʁpʁiz tut sa vi kil pɑ˜sɛ sɑ˜z istwaʁ lyi ʁəvjɛ˜t ɑ˜ memwaʁ il sɔʁ le muʃwaʁ bʁɔde paʁ sa ɡʁɑ˜mɛʁ se pətit dɑ˜ də lɛ sɔ˜ po də ʃɑ˜bʁ ebʁeʃe yn tɛt də pwasɔ˜ seʃe œ˜ sak plɛ˜ də bijz yn mɔ˜tʁ ki fɛ tik tak tik tak sɔ˜ kaʁnɛ də nɔtz œ˜ bu də lasɛ sɔ˜ vjø tʁɑ˜zistɔʁ a pil sɛ fu kɔm tu se suvniʁ sə buskyl dɑ˜ sa tɛt e il nə pø ʁətniʁ se laʁm demɔsjɔ˜ sa vi nɛ pa sɑ˜z istwaʁ il sə suvjɛ˜t ɛɡzaktəmɑ̃ də la vwa dy pʁezɑ˜tatœʁ meteo lə tɑ˜ va sameljɔʁe dəmɛ˜ ɑ˜ deby də matine syʁ nɔtʁ ʁeʒjɔ˜ sjɛl ʃaʁʒe lapʁɛmidi il sə ʁapɛl le vjɛj pyblisitez aɛma e la salte sɑ̃ va ɔ˜n a tuʒuʁ bəzwɛ˜ də pəti pwa ʃe swa le pʁəmjɛʁ lymjɛʁ dy ʒuʁ penɛtʁ paʁ la pətit fənɛtʁ dy ɡʁənje il ɛt o kœʁ də se suvniʁ kɑ˜ sɔ˜ ʁevɛj sɔndʁɪŋ dʁɪŋ dʁɪŋ'.split(" ")

# For each of the tests, we will evaluate the top 3 phoneme transcriptions
for test_id in tests_id:
    print("==" * 20)
    print(f"Test ID: {test_id}")

    # We evaluate the test results for each of the tests    
    top_3_phoneme_evaluation(readingTestFluencE_df, test_id, ground_truth, buffer_size=10, detailed=True)

# %%
# We generate the top-3 phoneme transcriptions for the selected tests
top_3_phoneme_transcriptions_with_proba(tests_id=tests_id)

# %%
# The full text of the readingTestFluencE
ground_truth = 'sɛ listwaʁ də møsjø pəti ki vi dɑ˜z yn vjɛj mɛzɔ˜ sitye o kœʁ dœ˜ vjø vilaʒ la mɛzɔ˜ ɛt ɑ˜tuʁe dœ˜ ʒaʁdɛ˜ avɛk yn baʁjɛʁ il i a de kɔ˜kɔ˜bʁ de ʃu fʁize tut sɔʁt də leɡymz o fɔ˜ dy ʒaʁdɛ˜ lə pɔʁtijɔ˜ ʁɛst tuʒuʁ fɛʁme puʁ kə ʃjɛ˜ a pys nə seʃap pa ʃjɛ˜ a pysz ɛm sə kuʃe pʁɛ də la pubɛl a lɔ˜bʁ dœ˜n ɔʁɑ˜ʒe kuvɛʁ də fʁyi delisjø ʃjɛ˜ a pysz ɛ ɡuʁmɑ˜ il kʁɔk tu sə ki lyi pas su la dɑ˜ dez ɔʁɑ˜ʒ puʁi ki tɔ˜b syʁ lə sɔl de flœʁ fanez œ˜ mɔʁso də byvaʁ œ˜ ʒuʁ məsjø pəti desid də mɛtʁ ʃjɛ̃ a pys dɑ˜z yn niʃ ʃjɛ˜ a pys nɛm paz ɛtʁ ɑ˜fɛʁme il pʁefɛʁ sɑ˜dɔʁmiʁ ɑ˜ ʁəɡaʁdɑ˜ lez etwal dɑ˜ lə sjɛl tut le nyiz il abwa kɑ˜ məsjø pəti va sə kuʃe məsjø pəti desid də dɔʁmiʁ dɑ˜ lə ɡʁənje də sa ʒɔli mɛzɔ˜ puʁ pʁɑ˜dʁ œ˜ pø də ʁəpoz il nə tʁuv ply lə sɔmɛj yn nyi dɛ˜sɔmni ɔp il sot dy li e uvʁ la ɡʁɑ˜d mal ki sə tʁuv dəvɑ˜ lyi dɑ˜z œ˜ kwɛ˜ sɔ˜bʁ dy ɡʁənje e la syʁpʁiz tut sa vi kil pɑ˜sɛ sɑ˜z istwaʁ lyi ʁəvjɛ˜t ɑ˜ memwaʁ il sɔʁ le muʃwaʁ bʁɔde paʁ sa ɡʁɑ˜mɛʁ se pətit dɑ˜ də lɛ sɔ˜ po də ʃɑ˜bʁ ebʁeʃe yn tɛt də pwasɔ˜ seʃe œ˜ sak plɛ˜ də bijz yn mɔ˜tʁ ki fɛ tik tak tik tak sɔ˜ kaʁnɛ də nɔtz œ˜ bu də lasɛ sɔ˜ vjø tʁɑ˜zistɔʁ a pil sɛ fu kɔm tu se suvniʁ sə buskyl dɑ˜ sa tɛt e il nə pø ʁətniʁ se laʁm demɔsjɔ˜ sa vi nɛ pa sɑ˜z istwaʁ il sə suvjɛ˜t ɛɡzaktəmɑ̃ də la vwa dy pʁezɑ˜tatœʁ meteo lə tɑ˜ va sameljɔʁe dəmɛ˜ ɑ˜ deby də matine syʁ nɔtʁ ʁeʒjɔ˜ sjɛl ʃaʁʒe lapʁɛmidi il sə ʁapɛl le vjɛj pyblisitez aɛma e la salte sɑ̃ va ɔ˜n a tuʒuʁ bəzwɛ˜ də pəti pwa ʃe swa le pʁəmjɛʁ lymjɛʁ dy ʒuʁ penɛtʁ paʁ la pətit fənɛtʁ dy ɡʁənje il ɛt o kœʁ də se suvniʁ kɑ˜ sɔ˜ ʁevɛj sɔndʁɪŋ dʁɪŋ dʁɪŋ'.split(" ")

# For each of the tests, we will evaluate the top 3 phoneme transcriptions
for test_id in tests_id:
    print("==" * 20)
    print(f"Test ID: {test_id}")

    # We evaluate the test results for each of the tests
    word_results = top_3_phoneme_evaluation_with_proba(readingTestFluencE_df, test_id, ground_truth, detailed=True)
# Out:
# ========================================
# Test ID: 2BB671AA-2F6A-4346-8B76-F0C89C236390
#
# ❌ False Positives: 1
# ❌ False Negatives: 0
# Detailed Evaluation:
# ⚠️✅ C'est → uncertain_correct
# ✅ l'histoire → correct
# ✅ de → correct
# ⚠️❌ Monsieur → uncertain_incorrect
# ✅ Petit → correct
# ✅ qui → correct
# ✅ vit → correct
# ✅ dans → correct
# ✅ une → correct
# ⚠️❌ vieille → uncertain_incorrect
# ✅ maison → correct
# ⚠️❌ située → uncertain_incorrect
# ✅ au → correct
# ⚠️❌ coeur → uncertain_incorrect
# ❌ d'un → incorrect
# ⚠️❌ vieux → uncertain_incorrect
# ⚠️❌ village. → uncertain_incorrect
# ✅ La → correct
# ✅ maison → correct
# ⚠️❌ est → uncertain_incorrect
# ⚠️❌ entourée → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ⚠️✅ jardin → uncertain_correct
# ⚠️❌ avec → uncertain_incorrect
# ✅ une → correct
# ⚠️❌ barrière → uncertain_incorrect
# ⚠️❌ ; → uncertain_incorrect
# ✅ il → correct
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ✅ concombres, → correct
# ⚠️✅ des → uncertain_correct
# ⚠️❌ choux → uncertain_incorrect
# ⚠️❌ frisés, → uncertain_incorrect
# ⚠️❌ toutes → uncertain_incorrect
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ⚠️✅ Au → uncertain_correct
# ✅ fond → correct
# ⚠️❌ du → uncertain_incorrect
# ✅ jardin, → correct
# ⚠️❌ le → uncertain_incorrect
# ⚠️❌ portillon → uncertain_incorrect
# ✅ reste → correct
# ✅ toujours → correct
# ✅ fermé → correct
# ✅ pour → correct
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ✅ Chien → correct
#
# Final Score: 28/57 words read correctly.
#
# State Counts:
# uncertain_correct: 4
# correct: 28
# uncertain_incorrect: 24
# incorrect: 1
# ========================================
# Test ID: 3B545E56-D802-4380-9993-21C11066B12E
#
# ❌ False Positives: 0
# ❌ False Negatives: 7
# Detailed Evaluation:
# ❌ C'est → incorrect
# ⚠️❌ l'histoire → uncertain_incorrect
# ⚠️❌ de → uncertain_incorrect
# ❌ Monsieur → incorrect
# ✅ Petit → correct
# ✅ qui → correct
# ❌ vit → incorrect
# ❌ dans → incorrect
# ⚠️❌ une → uncertain_incorrect
# ❌ vieille → incorrect
# ⚠️❌ maison → uncertain_incorrect
# ⚠️❌ située → uncertain_incorrect
# ✅ au → correct
# ⚠️❌ coeur → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ⚠️❌ vieux → uncertain_incorrect
# ⚠️❌ village. → uncertain_incorrect
# ✅ La → correct
# ✅ maison → correct
# ✅ est → correct
# ✅ entourée → correct
# ⚠️❌ d'un → uncertain_incorrect
# ⚠️✅ jardin → uncertain_correct
# ⚠️❌ avec → uncertain_incorrect
# ❌ une → incorrect
# ✅ barrière → correct
# ⚠️❌ ; → uncertain_incorrect
# ✅ il → correct
# ❌ y → incorrect
# ⚠️❌ a → uncertain_incorrect
# ⚠️❌ des → uncertain_incorrect
# ⚠️❌ concombres, → uncertain_incorrect
# ✅ des → correct
# ✅ choux → correct
# ✅ frisés, → correct
# ✅ toutes → correct
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ✅ Au → correct
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ⚠️❌ le → uncertain_incorrect
# ⚠️❌ portillon → uncertain_incorrect
# ✅ reste → correct
# ✅ toujours → correct
# ✅ fermé → correct
# ✅ pour → correct
# ✅ que → correct
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️✅ Puces → uncertain_correct
# ✅ aime → correct
# ✅ se → correct
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ✅ poubelle, → correct
# ⚠️❌ à → uncertain_incorrect
#
# Final Score: 34/67 words read correctly.
#
# State Counts:
# incorrect: 7
# uncertain_incorrect: 24
# correct: 34
# uncertain_correct: 2
# ========================================
# Test ID: 5C1C826F-E778-48C3-9170-6BF943175984
#
# ❌ False Positives: 0
# ❌ False Negatives: 13
# Detailed Evaluation:
# ❌ C'est → incorrect
# ⚠️✅ l'histoire → uncertain_correct
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ⚠️✅ Petit → uncertain_correct
# ⚠️❌ qui → uncertain_incorrect
# ✅ vit → correct
# ⚠️❌ dans → uncertain_incorrect
# ❌ une → incorrect
# ⚠️❌ vieille → uncertain_incorrect
# ✅ maison → correct
# ⚠️❌ située → uncertain_incorrect
# ✅ au → correct
# ✅ coeur → correct
# ✅ d'un → correct
# ✅ vieux → correct
# ✅ village. → correct
# ⚠️❌ La → uncertain_incorrect
# ⚠️❌ maison → uncertain_incorrect
# ⚠️❌ est → uncertain_incorrect
# ✅ entourée → correct
# ⚠️❌ d'un → uncertain_incorrect
# ✅ jardin → correct
# ✅ avec → correct
# ❌ une → incorrect
# ⚠️❌ barrière → uncertain_incorrect
# ✅ ; → correct
# ✅ il → correct
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ✅ concombres, → correct
# ✅ des → correct
# ✅ choux → correct
# ⚠️❌ frisés, → uncertain_incorrect
# ⚠️❌ toutes → uncertain_incorrect
# ⚠️✅ sortes → uncertain_correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ⚠️❌ Au → uncertain_incorrect
# ⚠️❌ fond → uncertain_incorrect
# ⚠️❌ du → uncertain_incorrect
# ⚠️✅ jardin, → uncertain_correct
# ⚠️❌ le → uncertain_incorrect
# ✅ portillon → correct
# ⚠️❌ reste → uncertain_incorrect
# ⚠️✅ toujours → uncertain_correct
# ✅ fermé → correct
# ⚠️❌ pour → uncertain_incorrect
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ✅ à → correct
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️✅ Puces → uncertain_correct
# ✅ aime → correct
# ✅ se → correct
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ✅ poubelle, → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ l'ombre → uncertain_incorrect
# ✅ d'un → correct
# ⚠️❌ oranger → uncertain_incorrect
# ✅ couvert → correct
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ fruits → uncertain_incorrect
# ✅ délicieux. → correct
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ⚠️❌ est → uncertain_incorrect
# ✅ gourmand, → correct
# ⚠️✅ il → uncertain_correct
# ✅ croque → correct
# ✅ tout → correct
# ✅ ce → correct
# ✅ qui → correct
# ✅ lui → correct
# ⚠️❌ passe → uncertain_incorrect
# ⚠️❌ sous → uncertain_incorrect
# ✅ la → correct
# ⚠️❌ dent → uncertain_incorrect
# ⚠️❌ : → uncertain_incorrect
# ⚠️❌ des → uncertain_incorrect
# ✅ oranges → correct
# ✅ pourries → correct
# ⚠️❌ qui → uncertain_incorrect
# ❌ tombent → incorrect
# ❌ sur → incorrect
# ❌ le → incorrect
# ⚠️❌ sol, → uncertain_incorrect
# ⚠️❌ des → uncertain_incorrect
# ⚠️❌ fleurs → uncertain_incorrect
# ⚠️❌ fanées, → uncertain_incorrect
# ⚠️✅ un → uncertain_correct
# ❌ morceau → incorrect
# ⚠️✅ de → uncertain_correct
# ❌ buvard... → incorrect
# ❌ Un → incorrect
# ⚠️❌ jour, → uncertain_incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ⚠️❌ Petit → uncertain_incorrect
# ⚠️❌ décide → uncertain_incorrect
# ⚠️❌ de → uncertain_incorrect
# ✅ mettre → correct
# ❌ Chien → incorrect
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ❌ dans → incorrect
# ⚠️❌ une → uncertain_incorrect
# ⚠️✅ niche. → uncertain_correct
# ❌ Chien → incorrect
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ✅ n'aime → correct
# ✅ pas → correct
# ✅ être → correct
# ❌ enfermé, → incorrect
# ❌ il → incorrect
# ❌ préfère → incorrect
# ❌ s'endormir → incorrect
# ⚠️❌ en → uncertain_incorrect
# ✅ regardant → correct
#
# Final Score: 52/130 words read correctly.
#
# State Counts:
# incorrect: 16
# uncertain_correct: 10
# uncertain_incorrect: 52
# correct: 52
# ========================================
# Test ID: 046E4FEB-E284-48D5-922E-616DA7651F02
#
# ❌ False Positives: 0
# ❌ False Negatives: 8
# Detailed Evaluation:
# ⚠️✅ C'est → uncertain_correct
# ✅ l'histoire → correct
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ✅ Petit → correct
# ⚠️✅ qui → uncertain_correct
# ✅ vit → correct
# ⚠️❌ dans → uncertain_incorrect
# ✅ une → correct
# ⚠️❌ vieille → uncertain_incorrect
# ✅ maison → correct
# ✅ située → correct
# ✅ au → correct
# ⚠️❌ coeur → uncertain_incorrect
# ✅ d'un → correct
# ✅ vieux → correct
# ✅ village. → correct
# ✅ La → correct
# ✅ maison → correct
# ✅ est → correct
# ✅ entourée → correct
# ⚠️❌ d'un → uncertain_incorrect
# ✅ jardin → correct
# ✅ avec → correct
# ✅ une → correct
# ✅ barrière → correct
# ✅ ; → correct
# ⚠️✅ il → uncertain_correct
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ✅ concombres, → correct
# ⚠️✅ des → uncertain_correct
# ✅ choux → correct
# ❌ frisés, → incorrect
# ❌ toutes → incorrect
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ✅ Au → correct
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ✅ le → correct
# ⚠️❌ portillon → uncertain_incorrect
# ✅ reste → correct
# ✅ toujours → correct
# ✅ fermé → correct
# ✅ pour → correct
# ✅ que → correct
# ✅ Chien → correct
# ✅ à → correct
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ✅ pas. → correct
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️✅ Puces → uncertain_correct
# ✅ aime → correct
# ⚠️❌ se → uncertain_incorrect
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ✅ poubelle, → correct
# ✅ à → correct
# ⚠️❌ l'ombre → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ✅ oranger → correct
# ✅ couvert → correct
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ fruits → uncertain_incorrect
# ✅ délicieux. → correct
# ❌ Chien → incorrect
# ⚠️❌ à → uncertain_incorrect
# ❌ Puces → incorrect
# ❌ est → incorrect
# ✅ gourmand, → correct
# ⚠️✅ il → uncertain_correct
# ✅ croque → correct
# ⚠️✅ tout → uncertain_correct
# ❌ ce → incorrect
# ⚠️❌ qui → uncertain_incorrect
# ❌ lui → incorrect
# ⚠️❌ passe → uncertain_incorrect
# ⚠️❌ sous → uncertain_incorrect
# ✅ la → correct
# ⚠️❌ dent → uncertain_incorrect
# ⚠️❌ : → uncertain_incorrect
# ✅ des → correct
# ✅ oranges → correct
# ✅ pourries → correct
# ✅ qui → correct
# ✅ tombent → correct
# ⚠️✅ sur → uncertain_correct
# ⚠️❌ le → uncertain_incorrect
# ⚠️❌ sol, → uncertain_incorrect
# ⚠️❌ des → uncertain_incorrect
# ✅ fleurs → correct
# ✅ fanées, → correct
# ⚠️❌ un → uncertain_incorrect
# ⚠️✅ morceau → uncertain_correct
# ❌ de → incorrect
# ❌ buvard... → incorrect
# ⚠️❌ Un → uncertain_incorrect
# ✅ jour, → correct
# ⚠️❌ Monsieur → uncertain_incorrect
# ✅ Petit → correct
# ✅ décide → correct
#
# Final Score: 63/110 words read correctly.
#
# State Counts:
# uncertain_correct: 9
# correct: 63
# uncertain_incorrect: 29
# incorrect: 9
# ========================================
# Test ID: 75A80925-F8CF-463D-AFED-5CC399848CC2
#
# ❌ False Positives: 0
# ❌ False Negatives: 8
# Detailed Evaluation:
# ✅ C'est → correct
# ⚠️❌ l'histoire → uncertain_incorrect
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ✅ Petit → correct
# ✅ qui → correct
# ✅ vit → correct
# ⚠️❌ dans → uncertain_incorrect
# ⚠️❌ une → uncertain_incorrect
# ⚠️❌ vieille → uncertain_incorrect
# ✅ maison → correct
# ⚠️❌ située → uncertain_incorrect
# ❌ au → incorrect
# ⚠️❌ coeur → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ⚠️❌ vieux → uncertain_incorrect
# ⚠️❌ village. → uncertain_incorrect
# ✅ La → correct
# ⚠️❌ maison → uncertain_incorrect
# ⚠️❌ est → uncertain_incorrect
# ⚠️❌ entourée → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ⚠️❌ jardin → uncertain_incorrect
# ⚠️❌ avec → uncertain_incorrect
# ❌ une → incorrect
# ⚠️❌ barrière → uncertain_incorrect
# ⚠️✅ ; → uncertain_correct
# ❌ il → incorrect
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ⚠️✅ concombres, → uncertain_correct
# ✅ des → correct
# ⚠️❌ choux → uncertain_incorrect
# ⚠️❌ frisés, → uncertain_incorrect
# ✅ toutes → correct
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ✅ Au → correct
# ⚠️❌ fond → uncertain_incorrect
# ⚠️❌ du → uncertain_incorrect
# ✅ jardin, → correct
# ⚠️✅ le → uncertain_correct
# ⚠️✅ portillon → uncertain_correct
# ⚠️❌ reste → uncertain_incorrect
# ⚠️✅ toujours → uncertain_correct
# ✅ fermé → correct
# ⚠️❌ pour → uncertain_incorrect
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ✅ à → correct
# ⚠️❌ Puces → uncertain_incorrect
# ✅ ne → correct
# ⚠️❌ s'échappe → uncertain_incorrect
# ❌ pas. → incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ✅ aime → correct
# ✅ se → correct
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ❌ poubelle, → incorrect
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ l'ombre → uncertain_incorrect
# ✅ d'un → correct
# ✅ oranger → correct
# ⚠️✅ couvert → uncertain_correct
# ❌ de → incorrect
# ⚠️❌ fruits → uncertain_incorrect
# ⚠️❌ délicieux. → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ❌ Puces → incorrect
# ⚠️✅ est → uncertain_correct
# ✅ gourmand, → correct
# ❌ il → incorrect
# ⚠️❌ croque → uncertain_incorrect
# ⚠️❌ tout → uncertain_incorrect
# ⚠️❌ ce → uncertain_incorrect
# ⚠️❌ qui → uncertain_incorrect
# ⚠️❌ lui → uncertain_incorrect
# ✅ passe → correct
#
# Final Score: 31/86 words read correctly.
#
# State Counts:
# correct: 31
# uncertain_incorrect: 40
# incorrect: 8
# uncertain_correct: 7
# ========================================
# Test ID: 102DCD09-43EA-434D-A590-0FA5C7C7C1B3
#
# ❌ False Positives: 0
# ❌ False Negatives: 1
# Detailed Evaluation:
# ✅ C'est → correct
# ⚠️❌ l'histoire → uncertain_incorrect
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ⚠️❌ Petit → uncertain_incorrect
# ✅ qui → correct
# ⚠️❌ vit → uncertain_incorrect
# ✅ dans → correct
# ✅ une → correct
# ✅ vieille → correct
# ✅ maison → correct
# ⚠️❌ située → uncertain_incorrect
# ✅ au → correct
# ✅ coeur → correct
# ✅ d'un → correct
# ⚠️❌ vieux → uncertain_incorrect
# ⚠️✅ village. → uncertain_correct
# ✅ La → correct
# ✅ maison → correct
# ⚠️❌ est → uncertain_incorrect
# ⚠️❌ entourée → uncertain_incorrect
# ✅ d'un → correct
# ⚠️✅ jardin → uncertain_correct
# ✅ avec → correct
# ✅ une → correct
# ✅ barrière → correct
# ✅ ; → correct
# ✅ il → correct
# ✅ y → correct
# ✅ a → correct
# ✅ des → correct
# ✅ concombres, → correct
# ✅ des → correct
# ⚠️❌ choux → uncertain_incorrect
# ⚠️✅ frisés, → uncertain_correct
# ✅ toutes → correct
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ✅ Au → correct
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ⚠️❌ le → uncertain_incorrect
# ✅ portillon → correct
# ✅ reste → correct
# ✅ toujours → correct
# ✅ fermé → correct
# ✅ pour → correct
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ✅ à → correct
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ⚠️✅ Chien → uncertain_correct
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ✅ aime → correct
# ✅ se → correct
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ✅ poubelle, → correct
# ✅ à → correct
# ⚠️✅ l'ombre → uncertain_correct
# ⚠️❌ d'un → uncertain_incorrect
# ✅ oranger → correct
# ✅ couvert → correct
# ⚠️❌ de → uncertain_incorrect
# ⚠️❌ fruits → uncertain_incorrect
# ⚠️❌ délicieux. → uncertain_incorrect
# ⚠️✅ Chien → uncertain_correct
# ⚠️❌ à → uncertain_incorrect
# ✅ Puces → correct
# ✅ est → correct
# ✅ gourmand, → correct
# ⚠️❌ il → uncertain_incorrect
# ⚠️✅ croque → uncertain_correct
# ✅ tout → correct
# ✅ ce → correct
# ✅ qui → correct
# ✅ lui → correct
# ✅ passe → correct
# ✅ sous → correct
# ✅ la → correct
# ❌ dent → incorrect
# ⚠️❌ : → uncertain_incorrect
# ✅ des → correct
# ✅ oranges → correct
# ✅ pourries → correct
# ✅ qui → correct
#
# Final Score: 62/94 words read correctly.
#
# State Counts:
# correct: 62
# uncertain_incorrect: 24
# uncertain_correct: 7
# incorrect: 1
# ========================================
# Test ID: 098522E8-2203-425E-85E5-5809D5B0B523
#
# ❌ False Positives: 0
# ❌ False Negatives: 13
# Detailed Evaluation:
# ❌ C'est → incorrect
# ⚠️❌ l'histoire → uncertain_incorrect
# ❌ de → incorrect
# ⚠️❌ Monsieur → uncertain_incorrect
# ⚠️❌ Petit → uncertain_incorrect
# ⚠️❌ qui → uncertain_incorrect
# ⚠️❌ vit → uncertain_incorrect
# ⚠️❌ dans → uncertain_incorrect
# ⚠️❌ une → uncertain_incorrect
# ⚠️❌ vieille → uncertain_incorrect
# ⚠️❌ maison → uncertain_incorrect
# ⚠️✅ située → uncertain_correct
# ✅ au → correct
# ⚠️❌ coeur → uncertain_incorrect
# ⚠️❌ d'un → uncertain_incorrect
# ❌ vieux → incorrect
# ✅ village. → correct
# ✅ La → correct
# ✅ maison → correct
# ⚠️❌ est → uncertain_incorrect
# ⚠️❌ entourée → uncertain_incorrect
# ⚠️✅ d'un → uncertain_correct
# ❌ jardin → incorrect
# ✅ avec → correct
# ✅ une → correct
# ✅ barrière → correct
# ⚠️❌ ; → uncertain_incorrect
# ✅ il → correct
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ⚠️✅ concombres, → uncertain_correct
# ✅ des → correct
# ⚠️❌ choux → uncertain_incorrect
# ⚠️❌ frisés, → uncertain_incorrect
# ⚠️❌ toutes → uncertain_incorrect
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ❌ Au → incorrect
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ⚠️❌ le → uncertain_incorrect
# ✅ portillon → correct
# ⚠️❌ reste → uncertain_incorrect
# ⚠️❌ toujours → uncertain_incorrect
# ⚠️✅ fermé → uncertain_correct
# ⚠️✅ pour → uncertain_correct
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ✅ à → correct
# ❌ Puces → incorrect
# ❌ ne → incorrect
# ❌ s'échappe → incorrect
# ❌ pas. → incorrect
# ❌ Chien → incorrect
# ❌ à → incorrect
# ❌ Puces → incorrect
# ❌ aime → incorrect
# ❌ se → incorrect
#
# Final Score: 19/61 words read correctly.
#
# State Counts:
# incorrect: 14
# uncertain_incorrect: 23
# uncertain_correct: 5
# correct: 19
# ========================================
# Test ID: 79055215-1979-42D3-9B26-B9C6DD935D83
#
# ❌ False Positives: 1
# ❌ False Negatives: 6
# Detailed Evaluation:
# ✅ C'est → correct
# ⚠️❌ l'histoire → uncertain_incorrect
# ✅ de → correct
# ⚠️❌ Monsieur → uncertain_incorrect
# ✅ Petit → correct
# ✅ qui → correct
# ⚠️❌ vit → uncertain_incorrect
# ⚠️❌ dans → uncertain_incorrect
# ⚠️❌ une → uncertain_incorrect
# ❌ vieille → incorrect
# ⚠️❌ maison → uncertain_incorrect
# ✅ située → correct
# ✅ au → correct
# ⚠️❌ coeur → uncertain_incorrect
# ⚠️✅ d'un → uncertain_correct
# ⚠️❌ vieux → uncertain_incorrect
# ✅ village. → correct
# ✅ La → correct
# ✅ maison → correct
# ⚠️✅ est → uncertain_correct
# ⚠️❌ entourée → uncertain_incorrect
# ✅ d'un → correct
# ✅ jardin → correct
# ✅ avec → correct
# ✅ une → correct
# ⚠️❌ barrière → uncertain_incorrect
# ✅ ; → correct
# ❌ il → incorrect
# ✅ y → correct
# ✅ a → correct
# ⚠️✅ des → uncertain_correct
# ✅ concombres, → correct
# ✅ des → correct
# ⚠️❌ choux → uncertain_incorrect
# ⚠️✅ frisés, → uncertain_correct
# ✅ toutes → correct
# ✅ sortes → correct
# ⚠️❌ de → uncertain_incorrect
# ✅ légumes. → correct
# ⚠️❌ Au → uncertain_incorrect
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ⚠️❌ le → uncertain_incorrect
# ✅ portillon → correct
# ⚠️❌ reste → uncertain_incorrect
# ⚠️❌ toujours → uncertain_incorrect
# ✅ fermé → correct
# ✅ pour → correct
# ⚠️❌ que → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️✅ Puces → uncertain_correct
# ✅ aime → correct
# ✅ se → correct
# ✅ coucher → correct
# ✅ près → correct
# ✅ de → correct
# ✅ la → correct
# ✅ poubelle, → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ l'ombre → uncertain_incorrect
# ⚠️✅ d'un → uncertain_correct
# ✅ oranger → correct
# ✅ couvert → correct
# ✅ de → correct
# ⚠️❌ fruits → uncertain_incorrect
# ⚠️❌ délicieux. → uncertain_incorrect
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ❌ Puces → incorrect
# ⚠️❌ est → uncertain_incorrect
# ✅ gourmand, → correct
# ⚠️✅ il → uncertain_correct
# ⚠️❌ croque → uncertain_incorrect
# ✅ tout → correct
# ❌ ce → incorrect
# ❌ qui → incorrect
# ❌ lui → incorrect
#
# Final Score: 43/85 words read correctly.
#
# State Counts:
# correct: 43
# uncertain_incorrect: 29
# incorrect: 6
# uncertain_correct: 7
# ========================================
# Test ID: ABD81BE7-7629-4816-8241-7ECBF32DFFFA
#
# ❌ False Positives: 0
# ❌ False Negatives: 3
# Detailed Evaluation:
# ❌ C'est → incorrect
# ⚠️❌ l'histoire → uncertain_incorrect
# ✅ de → correct
# ⚠️✅ Monsieur → uncertain_correct
# ✅ Petit → correct
# ✅ qui → correct
# ✅ vit → correct
# ✅ dans → correct
# ✅ une → correct
# ⚠️❌ vieille → uncertain_incorrect
# ✅ maison → correct
# ✅ située → correct
# ✅ au → correct
# ✅ coeur → correct
# ⚠️✅ d'un → uncertain_correct
# ✅ vieux → correct
# ✅ village. → correct
# ✅ La → correct
# ✅ maison → correct
# ⚠️❌ est → uncertain_incorrect
# ⚠️✅ entourée → uncertain_correct
# ✅ d'un → correct
# ✅ jardin → correct
# ✅ avec → correct
# ✅ une → correct
# ✅ barrière → correct
# ✅ ; → correct
# ✅ il → correct
# ✅ y → correct
# ✅ a → correct
# ⚠️❌ des → uncertain_incorrect
# ✅ concombres, → correct
# ✅ des → correct
# ⚠️✅ choux → uncertain_correct
# ✅ frisés, → correct
# ✅ toutes → correct
# ✅ sortes → correct
# ❌ de → incorrect
# ✅ légumes. → correct
# ✅ Au → correct
# ✅ fond → correct
# ✅ du → correct
# ✅ jardin, → correct
# ✅ le → correct
# ✅ portillon → correct
# ✅ reste → correct
# ✅ toujours → correct
# ✅ fermé → correct
# ✅ pour → correct
# ⚠️✅ que → uncertain_correct
# ✅ Chien → correct
# ⚠️❌ à → uncertain_incorrect
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️❌ ne → uncertain_incorrect
# ✅ s'échappe → correct
# ⚠️❌ pas. → uncertain_incorrect
# ✅ Chien → correct
# ❌ à → incorrect
# ⚠️❌ Puces → uncertain_incorrect
# ⚠️✅ aime → uncertain_correct
# ⚠️❌ se → uncertain_incorrect
#
# Final Score: 42/61 words read correctly.
#
# State Counts:
# incorrect: 3
# uncertain_incorrect: 10
# correct: 42
# uncertain_correct: 6
