# %%
import os
from dotenv import load_dotenv
import pandas as pd
import azure.cognitiveservices.speech as speechsdk
import time
import json
import difflib
import string
from src.text_processing import *
from src.data_processing import *
from src.ui_tools import *
from src.audio_processing import *

# Add espeak's shared library directory
os.environ['DYLD_LIBRARY_PATH'] = '/opt/homebrew/lib'

# %%
# Load the cleaned data
data_path = 'data/df_test_cleaned.csv'
tests_df = pd.read_csv(data_path)

# We only keep the rows where the testType is readingTestFluencE
readingTestFluencE_df = tests_df[tests_df['testType'] == 'readingTestFluencE']

# Apply conversion functions to testResults and evaluationResults columns
readingTestFluencE_df['testResults'] = readingTestFluencE_df['testResults'].apply(lambda x: convert_str_to_dct_eval(x))
readingTestFluencE_df['evaluationResults'] = readingTestFluencE_df['evaluationResults'].apply(lambda x: convert_str_to_dct_eval(x))
# Out:
# /var/folders/kn/xrv1vh8j0k99dnh2mwl662xc0000gn/T/ipykernel_2174/537599615.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   readingTestFluencE_df['testResults'] = readingTestFluencE_df['testResults'].apply(lambda x: convert_str_to_dct_eval(x))
# /var/folders/kn/xrv1vh8j0k99dnh2mwl662xc0000gn/T/ipykernel_2174/537599615.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   readingTestFluencE_df['evaluationResults'] = readingTestFluencE_df['evaluationResults'].apply(lambda x: convert_str_to_dct_eval(x))

# %%
# We extract the row with id = 75A80925-F8CF-463D-AFED-5CC399848CC2
test_id = '75A80925-F8CF-463D-AFED-5CC399848CC2'
test_row = readingTestFluencE_df[readingTestFluencE_df['id'] == test_id]

evaluation_result = test_row['evaluationResults'].apply(
    lambda x: x['wordsState'] if 'wordsState' in x else None).dropna().tolist()

# We discard all the element that are 'NonRead'
read_words = [[d for d in row if list(d.values())[0] != "NonRead"] for row in evaluation_result]

# We create a string with the words that were read
reference_text = ' '.join([list(d.keys())[0] for row in read_words for d in row])

audio_file = f"sample_readingTestFluencE/readingTestFluencE_{test_id}.wav"

# %%
print(reference_text)
# Out:
# C'est l'histoire de Monsieur Petit qui vit dans une vieille maison située au coeur d'un vieux village. La maison est entourée d'un jardin avec une barrière ;il y a des concombres, des choux frisés, toutes sortes de légumes. Au fond du jardin, le portillon reste toujours fermé pour que Chien à Puces ne s'échappe pas. Chien à Puces aime se coucher près de la poubelle, à l'ombre d'un oranger couvert de fruits délicieux. Chien à Puces est gourmand, il croque tout ce qui lui passe sous

# %%
load_dotenv()  # Load environment variables from .env file

speech_key = os.getenv("AZURE_SPEECH_KEY")
service_region = os.getenv("AZURE_REGION")

# %%
def assess_pronunciation_continuous(audio_file: str, reference_text: str):
    """Performs continuous pronunciation assessment for a long audio file."""
    
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    audio_config = speechsdk.audio.AudioConfig(filename=audio_file)

    pronunciation_config = speechsdk.PronunciationAssessmentConfig(
        reference_text=reference_text,
        grading_system=speechsdk.PronunciationAssessmentGradingSystem.HundredMark,
        granularity=speechsdk.PronunciationAssessmentGranularity.Phoneme,
        enable_miscue=True,
    )

    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, language="en-US", audio_config=audio_config)
    pronunciation_config.apply_to(speech_recognizer)

    done = False
    recognized_words = []
    prosody_scores = []
    fluency_scores = []
    durations = []

    def stop_cb(evt: speechsdk.SessionEventArgs):
        """Stops the recognition process"""
        nonlocal done
        done = True

    def recognized(evt: speechsdk.SpeechRecognitionEventArgs):
        """Handles recognized speech"""
        pronunciation_result = speechsdk.PronunciationAssessmentResult(evt.result)
        recognized_words.extend(pronunciation_result.words)
        fluency_scores.append(pronunciation_result.fluency_score)
        if pronunciation_result.prosody_score is not None:
            prosody_scores.append(pronunciation_result.prosody_score)
        json_result = evt.result.properties.get(speechsdk.PropertyId.SpeechServiceResponse_JsonResult)
        jo = json.loads(json_result)
        nb = jo["NBest"][0]
        durations.append(sum([int(w["Duration"]) for w in nb["Words"]]))

    # Attach event handlers
    speech_recognizer.recognized.connect(recognized)
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(0.5)
    
    speech_recognizer.stop_continuous_recognition()

    # Process results
    reference_words = [w.strip(string.punctuation) for w in reference_text.lower().split()]
    diff = difflib.SequenceMatcher(None, reference_words, [x.word.lower() for x in recognized_words])
    final_words = []
    
    for tag, i1, i2, j1, j2 in diff.get_opcodes():
        if tag in ['insert', 'replace']:
            for word in recognized_words[j1:j2]:
                if word.error_type == 'None':
                    word._error_type = 'Insertion'
                final_words.append(word)
        if tag in ['delete', 'replace']:
            for word_text in reference_words[i1:i2]:
                word = speechsdk.PronunciationAssessmentWordResult({
                    'Word': word_text,
                    'PronunciationAssessment': {'ErrorType': 'Omission'}
                })
                final_words.append(word)
        if tag == 'equal':
            final_words += recognized_words[j1:j2]

    # Calculate final scores
    accuracy_scores = [word.accuracy_score for word in final_words if word.error_type != 'Insertion']
    accuracy_score = sum(accuracy_scores) / len(accuracy_scores) if accuracy_scores else 0
    prosody_score = sum(prosody_scores) / len(prosody_scores) if prosody_scores else 0
    fluency_score = sum([x * y for (x, y) in zip(fluency_scores, durations)]) / sum(durations) if durations else 0
    completeness_score = len([w for w in recognized_words if w.error_type == "None"]) / len(reference_words) * 100
    completeness_score = min(completeness_score, 100)

    # Print results
    print(f'Accuracy: {accuracy_score:.2f}, Prosody: {prosody_score:.2f}, Fluency: {fluency_score:.2f}, Completeness: {completeness_score:.2f}')
    for idx, word in enumerate(final_words):
        print(f'{idx + 1}: {word.word} - Accuracy: {word.accuracy_score}, Error Type: {word.error_type}')

# %%
assess_pronunciation_continuous(audio_file=audio_file, reference_text=reference_text)
# Out:
# Accuracy: 9.18, Prosody: 0.00, Fluency: 41.68, Completeness: 3.49
# 1: se - Accuracy: 88.0, Error Type: Insertion
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 50.0, Error Type: Mispronunciation
# 4: de - Accuracy: 80.0, Error Type: None
# 5: monsieur - Accuracy: 42.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 52.0, Error Type: Mispronunciation
# 7: qui - Accuracy: 8.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 11.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 12.0, Error Type: Mispronunciation
# 10: portillon - Accuracy: 11.0, Error Type: Mispronunciation
# 11: une - Accuracy: 0, Error Type: Omission
# 12: vieille - Accuracy: 0, Error Type: Omission
# 13: maison - Accuracy: 0, Error Type: Omission
# 14: située - Accuracy: 0, Error Type: Omission
# 15: au - Accuracy: 0, Error Type: Omission
# 16: coeur - Accuracy: 0, Error Type: Omission
# 17: d'un - Accuracy: 0, Error Type: Omission
# 18: vieux - Accuracy: 0, Error Type: Omission
# 19: village - Accuracy: 0, Error Type: Omission
# 20: la - Accuracy: 0, Error Type: Omission
# 21: maison - Accuracy: 0, Error Type: Omission
# 22: est - Accuracy: 0, Error Type: Omission
# 23: entourée - Accuracy: 0, Error Type: Omission
# 24: d'un - Accuracy: 0, Error Type: Omission
# 25: jardin - Accuracy: 0, Error Type: Omission
# 26: avec - Accuracy: 0, Error Type: Omission
# 27: une - Accuracy: 0, Error Type: Omission
# 28: barrière - Accuracy: 0, Error Type: Omission
# 29: il - Accuracy: 0, Error Type: Omission
# 30: y - Accuracy: 0, Error Type: Omission
# 31: a - Accuracy: 0, Error Type: Omission
# 32: des - Accuracy: 0, Error Type: Omission
# 33: concombres - Accuracy: 0, Error Type: Omission
# 34: des - Accuracy: 0, Error Type: Omission
# 35: choux - Accuracy: 0, Error Type: Omission
# 36: frisés - Accuracy: 0, Error Type: Omission
# 37: toutes - Accuracy: 0, Error Type: Omission
# 38: sortes - Accuracy: 0, Error Type: Omission
# 39: de - Accuracy: 0, Error Type: Omission
# 40: légumes - Accuracy: 0, Error Type: Omission
# 41: au - Accuracy: 0, Error Type: Omission
# 42: fond - Accuracy: 0, Error Type: Omission
# 43: du - Accuracy: 0, Error Type: Omission
# 44: jardin - Accuracy: 0, Error Type: Omission
# 45: le - Accuracy: 0, Error Type: Omission
# 46: portillon - Accuracy: 38.0, Error Type: Mispronunciation
# 47: reste - Accuracy: 78.0, Error Type: None
# 48: toujours - Accuracy: 12.0, Error Type: Mispronunciation
# 49: fermé - Accuracy: 26.0, Error Type: Mispronunciation
# 50: pour - Accuracy: 48.0, Error Type: Mispronunciation
# 51: choux - Accuracy: 18.0, Error Type: Mispronunciation
# 52: que - Accuracy: 0, Error Type: Omission
# 53: chien - Accuracy: 0, Error Type: Omission
# 54: à - Accuracy: 0, Error Type: Omission
# 55: puces - Accuracy: 0, Error Type: Omission
# 56: ne - Accuracy: 0, Error Type: Omission
# 57: s'échappe - Accuracy: 0, Error Type: Omission
# 58: pas - Accuracy: 0, Error Type: Omission
# 59: chien - Accuracy: 0, Error Type: Omission
# 60: à - Accuracy: 0, Error Type: Omission
# 61: puces - Accuracy: 0, Error Type: Omission
# 62: aime - Accuracy: 0, Error Type: Omission
# 63: se - Accuracy: 0, Error Type: Omission
# 64: coucher - Accuracy: 0, Error Type: Omission
# 65: près - Accuracy: 0, Error Type: Omission
# 66: de - Accuracy: 0, Error Type: Omission
# 67: la - Accuracy: 0, Error Type: Omission
# 68: poubelle - Accuracy: 0, Error Type: Omission
# 69: à - Accuracy: 0, Error Type: Omission
# 70: l'ombre - Accuracy: 0, Error Type: Omission
# 71: d'un - Accuracy: 0, Error Type: Omission
# 72: oranger - Accuracy: 0, Error Type: Omission
# 73: couvert - Accuracy: 27.0, Error Type: Mispronunciation
# 74: de - Accuracy: 0, Error Type: Omission
# 75: fruits - Accuracy: 0, Error Type: Omission
# 76: délicieux - Accuracy: 13.0, Error Type: Mispronunciation
# 77: choux - Accuracy: 50.0, Error Type: Mispronunciation
# 78: choux - Accuracy: 69.0, Error Type: Insertion
# 79: ce - Accuracy: 88.0, Error Type: Insertion
# 80: chien - Accuracy: 0, Error Type: Omission
# 81: à - Accuracy: 0, Error Type: Omission
# 82: puces - Accuracy: 0, Error Type: Omission
# 83: est - Accuracy: 0, Error Type: Omission
# 84: gourmand - Accuracy: 0, Error Type: Omission
# 85: il - Accuracy: 0, Error Type: Omission
# 86: croque - Accuracy: 11.0, Error Type: Mispronunciation
# 87: tout - Accuracy: 38.0, Error Type: Mispronunciation
# 88: ce - Accuracy: 66.0, Error Type: None
# 89: qui - Accuracy: 16.0, Error Type: Mispronunciation
# 90: lui - Accuracy: 18.0, Error Type: Mispronunciation
# 91: passe - Accuracy: 52.0, Error Type: Mispronunciation
# 92: sous - Accuracy: 40.0, Error Type: Mispronunciation
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.

# %% [markdown]
# ## AZURE model with the reference text

# %%
tests_id = [
    '2BB671AA-2F6A-4346-8B76-F0C89C236390',
    '3B545E56-D802-4380-9993-21C11066B12E',
    '5C1C826F-E778-48C3-9170-6BF943175984',
    '046E4FEB-E284-48D5-922E-616DA7651F02',
    '75A80925-F8CF-463D-AFED-5CC399848CC2',
    '102DCD09-43EA-434D-A590-0FA5C7C7C1B3',
    '098522E8-2203-425E-85E5-5809D5B0B523',
    '79055215-1979-42D3-9B26-B9C6DD935D83',
    'ABD81BE7-7629-4816-8241-7ECBF32DFFFA',
]

# We iterate over the tests_id and we evaluate each one
for test_id in tests_id:
    test_row = readingTestFluencE_df[readingTestFluencE_df['id'] == test_id]

    evaluation_result = test_row['evaluationResults'].apply(
        lambda x: x['wordsState'] if 'wordsState' in x else None).dropna().tolist()

    # We discard all the element that are 'NonRead'
    read_words = [[d for d in row if list(d.values())[0] != "NonRead"] for row in evaluation_result]
    reference_text = ' '.join([list(d.keys())[0] for row in read_words for d in row])
    audio_file = f"sample_readingTestFluencE/readingTestFluencE_{test_id}.wav"

    print('=' * 60)
    assess_pronunciation_continuous(audio_file=audio_file, reference_text=reference_text)
# Out:
# ============================================================
# Accuracy: 27.31, Prosody: 0.00, Fluency: 54.15, Completeness: 19.30
# 1: située - Accuracy: 0.0, Error Type: Mispronunciation
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 49.0, Error Type: Mispronunciation
# 4: de - Accuracy: 94.0, Error Type: None
# 5: monsieur - Accuracy: 55.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 60.0, Error Type: None
# 7: qui - Accuracy: 18.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 21.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 18.0, Error Type: Mispronunciation
# 10: une - Accuracy: 16.0, Error Type: Mispronunciation
# 11: vieille - Accuracy: 18.0, Error Type: Mispronunciation
# 12: maison - Accuracy: 52.0, Error Type: Mispronunciation
# 13: chien - Accuracy: 62.0, Error Type: Insertion
# 14: située - Accuracy: 0, Error Type: Omission
# 15: au - Accuracy: 76.0, Error Type: None
# 16: chien - Accuracy: 28.0, Error Type: Mispronunciation
# 17: coeur - Accuracy: 0, Error Type: Omission
# 18: d'un - Accuracy: 0, Error Type: Omission
# 19: vieux - Accuracy: 48.0, Error Type: Mispronunciation
# 20: vieille - Accuracy: 14.0, Error Type: Mispronunciation
# 21: village - Accuracy: 0, Error Type: Omission
# 22: la - Accuracy: 0, Error Type: Omission
# 23: maison - Accuracy: 36.0, Error Type: Mispronunciation
# 24: qui - Accuracy: 40.0, Error Type: Mispronunciation
# 25: vit - Accuracy: 55.0, Error Type: Mispronunciation
# 26: est - Accuracy: 0, Error Type: Omission
# 27: entourée - Accuracy: 0, Error Type: Omission
# 28: d'un - Accuracy: 0, Error Type: Omission
# 29: jardin - Accuracy: 0, Error Type: Omission
# 30: avec - Accuracy: 0, Error Type: Omission
# 31: une - Accuracy: 0, Error Type: Omission
# 32: barrière - Accuracy: 0, Error Type: Omission
# 33: il - Accuracy: 23.0, Error Type: Mispronunciation
# 34: y - Accuracy: 35.0, Error Type: Mispronunciation
# 35: a - Accuracy: 100.0, Error Type: None
# 36: des - Accuracy: 59.0, Error Type: Mispronunciation
# 37: concombres - Accuracy: 9.0, Error Type: Mispronunciation
# 38: de - Accuracy: 52.0, Error Type: Mispronunciation
# 39: qui - Accuracy: 70.0, Error Type: Insertion
# 40: située - Accuracy: 3.0, Error Type: Mispronunciation
# 41: du - Accuracy: 74.0, Error Type: Insertion
# 42: des - Accuracy: 0, Error Type: Omission
# 43: choux - Accuracy: 0, Error Type: Omission
# 44: frisés - Accuracy: 0, Error Type: Omission
# 45: toutes - Accuracy: 0, Error Type: Omission
# 46: sortes - Accuracy: 3.0, Error Type: Mispronunciation
# 47: de - Accuracy: 70.0, Error Type: Insertion
# 48: de - Accuracy: 90.0, Error Type: None
# 49: légumes - Accuracy: 47.0, Error Type: Mispronunciation
# 50: au - Accuracy: 80.0, Error Type: None
# 51: fond - Accuracy: 10.0, Error Type: Mispronunciation
# 52: au - Accuracy: 94.0, Error Type: Insertion
# 53: fond - Accuracy: 10.0, Error Type: Mispronunciation
# 54: du - Accuracy: 100.0, Error Type: None
# 55: s'échappe - Accuracy: 12.0, Error Type: Mispronunciation
# 56: d'un - Accuracy: 42.0, Error Type: Mispronunciation
# 57: jardin - Accuracy: 0, Error Type: Omission
# 58: le - Accuracy: 94.0, Error Type: None
# 59: portillon - Accuracy: 0, Error Type: Omission
# 60: reste - Accuracy: 0, Error Type: Omission
# 61: toujours - Accuracy: 24.0, Error Type: Mispronunciation
# 62: fermé - Accuracy: 52.0, Error Type: Mispronunciation
# 63: pour - Accuracy: 53.0, Error Type: Mispronunciation
# 64: choux - Accuracy: 29.0, Error Type: Mispronunciation
# 65: choux - Accuracy: 21.0, Error Type: Mispronunciation
# 66: qui - Accuracy: 18.0, Error Type: Mispronunciation
# 67: que - Accuracy: 0, Error Type: Omission
# 68: chien - Accuracy: 0, Error Type: Omission
# 69: à - Accuracy: 92.0, Error Type: None
# 70: puces - Accuracy: 12.0, Error Type: Mispronunciation
# 71: ne - Accuracy: 67.0, Error Type: None
# 72: choux - Accuracy: 31.0, Error Type: Mispronunciation
# 73: s'échappe - Accuracy: 0, Error Type: Omission
# 74: pas - Accuracy: 0, Error Type: Omission
# 75: chien - Accuracy: 0, Error Type: Omission
# 76: à - Accuracy: 73.0, Error Type: None
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 33.95, Prosody: 0.00, Fluency: 56.67, Completeness: 20.90
# 1: c'est - Accuracy: 4.0, Error Type: Mispronunciation
# 2: l'histoire - Accuracy: 45.0, Error Type: Mispronunciation
# 3: de - Accuracy: 80.0, Error Type: None
# 4: monsieur - Accuracy: 53.0, Error Type: Mispronunciation
# 5: petit - Accuracy: 53.0, Error Type: Mispronunciation
# 6: qui - Accuracy: 23.0, Error Type: Mispronunciation
# 7: vit - Accuracy: 30.0, Error Type: Mispronunciation
# 8: dans - Accuracy: 0, Error Type: Omission
# 9: une - Accuracy: 0, Error Type: Omission
# 10: vieille - Accuracy: 0, Error Type: Omission
# 11: maison - Accuracy: 22.0, Error Type: Mispronunciation
# 12: située - Accuracy: 33.0, Error Type: Mispronunciation
# 13: c'est - Accuracy: 61.0, Error Type: Insertion
# 14: au - Accuracy: 0, Error Type: Omission
# 15: coeur - Accuracy: 0, Error Type: Omission
# 16: d'un - Accuracy: 50.0, Error Type: Mispronunciation
# 17: vieux - Accuracy: 72.0, Error Type: None
# 18: village - Accuracy: 19.0, Error Type: Mispronunciation
# 19: la - Accuracy: 57.0, Error Type: Mispronunciation
# 20: maison - Accuracy: 49.0, Error Type: Mispronunciation
# 21: est - Accuracy: 2.0, Error Type: Mispronunciation
# 22: entourée - Accuracy: 46.0, Error Type: Mispronunciation
# 23: d'un - Accuracy: 48.0, Error Type: Mispronunciation
# 24: jardin - Accuracy: 4.0, Error Type: Mispronunciation
# 25: avec - Accuracy: 48.0, Error Type: Mispronunciation
# 26: une - Accuracy: 32.0, Error Type: Mispronunciation
# 27: barrière - Accuracy: 50.0, Error Type: Mispronunciation
# 28: il - Accuracy: 0, Error Type: Omission
# 29: y - Accuracy: 0, Error Type: Omission
# 30: a - Accuracy: 0, Error Type: Omission
# 31: des - Accuracy: 0, Error Type: Omission
# 32: concombres - Accuracy: 0, Error Type: Omission
# 33: des - Accuracy: 8.0, Error Type: Mispronunciation
# 34: choux - Accuracy: 69.0, Error Type: None
# 35: frisés - Accuracy: 15.0, Error Type: Mispronunciation
# 36: y - Accuracy: 60.0, Error Type: Insertion
# 37: toutes - Accuracy: 21.0, Error Type: Mispronunciation
# 38: se - Accuracy: 76.0, Error Type: Insertion
# 39: toutes - Accuracy: 14.0, Error Type: Mispronunciation
# 40: sortes - Accuracy: 12.0, Error Type: Mispronunciation
# 41: de - Accuracy: 100.0, Error Type: None
# 42: légumes - Accuracy: 30.0, Error Type: Mispronunciation
# 43: au - Accuracy: 92.0, Error Type: None
# 44: fond - Accuracy: 50.0, Error Type: Mispronunciation
# 45: du - Accuracy: 90.0, Error Type: None
# 46: jardin - Accuracy: 18.0, Error Type: Mispronunciation
# 47: le - Accuracy: 88.0, Error Type: None
# 48: portillon - Accuracy: 8.0, Error Type: Mispronunciation
# 49: reste - Accuracy: 15.0, Error Type: Mispronunciation
# 50: toujours - Accuracy: 29.0, Error Type: Mispronunciation
# 51: fermé - Accuracy: 51.0, Error Type: Mispronunciation
# 52: pour - Accuracy: 49.0, Error Type: Mispronunciation
# 53: que - Accuracy: 17.0, Error Type: Mispronunciation
# 54: chien - Accuracy: 25.0, Error Type: Mispronunciation
# 55: à - Accuracy: 84.0, Error Type: None
# 56: c'est - Accuracy: 2.0, Error Type: Mispronunciation
# 57: monsieur - Accuracy: 2.0, Error Type: Mispronunciation
# 58: puces - Accuracy: 0, Error Type: Omission
# 59: ne - Accuracy: 0, Error Type: Omission
# 60: s'échappe - Accuracy: 48.0, Error Type: Mispronunciation
# 61: choux - Accuracy: 20.0, Error Type: Mispronunciation
# 62: y - Accuracy: 80.0, Error Type: Insertion
# 63: a - Accuracy: 100.0, Error Type: Insertion
# 64: à - Accuracy: 60.0, Error Type: Insertion
# 65: pas - Accuracy: 0, Error Type: Omission
# 66: chien - Accuracy: 0, Error Type: Omission
# 67: à - Accuracy: 50.0, Error Type: Mispronunciation
# 68: puces - Accuracy: 3.0, Error Type: Mispronunciation
# 69: aime - Accuracy: 94.0, Error Type: None
# 70: y - Accuracy: 76.0, Error Type: Insertion
# 71: aime - Accuracy: 90.0, Error Type: Insertion
# 72: se - Accuracy: 84.0, Error Type: None
# 73: que - Accuracy: 59.0, Error Type: Mispronunciation
# 74: chien - Accuracy: 35.0, Error Type: Mispronunciation
# 75: coucher - Accuracy: 0, Error Type: Omission
# 76: près - Accuracy: 0, Error Type: Omission
# 77: de - Accuracy: 98.0, Error Type: None
# 78: la - Accuracy: 86.0, Error Type: None
# 79: poubelle - Accuracy: 92.0, Error Type: None
# 80: à - Accuracy: 96.0, Error Type: None
# 81: l'ombre - Accuracy: 4.0, Error Type: Mispronunciation
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 17.70, Prosody: 0.00, Fluency: 57.88, Completeness: 13.85
# 1: c'est - Accuracy: 0, Error Type: Omission
# 2: l'histoire - Accuracy: 0, Error Type: Omission
# 3: de - Accuracy: 0, Error Type: Omission
# 4: monsieur - Accuracy: 5.0, Error Type: Mispronunciation
# 5: petit - Accuracy: 49.0, Error Type: Mispronunciation
# 6: qui - Accuracy: 70.0, Error Type: None
# 7: vit - Accuracy: 0, Error Type: Omission
# 8: dans - Accuracy: 0, Error Type: Omission
# 9: une - Accuracy: 0, Error Type: Omission
# 10: vieille - Accuracy: 0, Error Type: Omission
# 11: maison - Accuracy: 0, Error Type: Omission
# 12: située - Accuracy: 0, Error Type: Omission
# 13: au - Accuracy: 0, Error Type: Omission
# 14: coeur - Accuracy: 0, Error Type: Omission
# 15: d'un - Accuracy: 0, Error Type: Omission
# 16: vieux - Accuracy: 0, Error Type: Omission
# 17: village - Accuracy: 0, Error Type: Omission
# 18: la - Accuracy: 0, Error Type: Omission
# 19: maison - Accuracy: 0, Error Type: Omission
# 20: est - Accuracy: 0, Error Type: Omission
# 21: entourée - Accuracy: 0, Error Type: Omission
# 22: d'un - Accuracy: 0, Error Type: Omission
# 23: jardin - Accuracy: 0, Error Type: Omission
# 24: avec - Accuracy: 0, Error Type: Omission
# 25: une - Accuracy: 0, Error Type: Omission
# 26: barrière - Accuracy: 0, Error Type: Omission
# 27: il - Accuracy: 0, Error Type: Omission
# 28: y - Accuracy: 0, Error Type: Omission
# 29: a - Accuracy: 0, Error Type: Omission
# 30: des - Accuracy: 0, Error Type: Omission
# 31: concombres - Accuracy: 0, Error Type: Omission
# 32: des - Accuracy: 0, Error Type: Omission
# 33: choux - Accuracy: 0, Error Type: Omission
# 34: frisés - Accuracy: 0, Error Type: Omission
# 35: toutes - Accuracy: 0, Error Type: Omission
# 36: sortes - Accuracy: 0, Error Type: Omission
# 37: de - Accuracy: 0, Error Type: Omission
# 38: légumes - Accuracy: 0, Error Type: Omission
# 39: au - Accuracy: 0, Error Type: Omission
# 40: fond - Accuracy: 0, Error Type: Omission
# 41: du - Accuracy: 0, Error Type: Omission
# 42: jardin - Accuracy: 0, Error Type: Omission
# 43: le - Accuracy: 0, Error Type: Omission
# 44: portillon - Accuracy: 0, Error Type: Omission
# 45: reste - Accuracy: 0, Error Type: Omission
# 46: toujours - Accuracy: 0, Error Type: Omission
# 47: fermé - Accuracy: 0, Error Type: Omission
# 48: pour - Accuracy: 0, Error Type: Omission
# 49: que - Accuracy: 0, Error Type: Omission
# 50: chien - Accuracy: 0, Error Type: Omission
# 51: à - Accuracy: 0, Error Type: Omission
# 52: puces - Accuracy: 0, Error Type: Omission
# 53: ne - Accuracy: 0, Error Type: Omission
# 54: s'échappe - Accuracy: 0, Error Type: Omission
# 55: pas - Accuracy: 0, Error Type: Omission
# 56: chien - Accuracy: 22.0, Error Type: Mispronunciation
# 57: à - Accuracy: 59.0, Error Type: Mispronunciation
# 58: puces - Accuracy: 6.0, Error Type: Mispronunciation
# 59: aime - Accuracy: 51.0, Error Type: Mispronunciation
# 60: se - Accuracy: 42.0, Error Type: Mispronunciation
# 61: coucher - Accuracy: 19.0, Error Type: Mispronunciation
# 62: près - Accuracy: 88.0, Error Type: None
# 63: de - Accuracy: 88.0, Error Type: None
# 64: la - Accuracy: 100.0, Error Type: None
# 65: poubelle - Accuracy: 98.0, Error Type: None
# 66: à - Accuracy: 100.0, Error Type: None
# 67: l'ombre - Accuracy: 15.0, Error Type: Mispronunciation
# 68: d'un - Accuracy: 0, Error Type: Omission
# 69: oranger - Accuracy: 0, Error Type: Omission
# 70: couvert - Accuracy: 28.0, Error Type: Mispronunciation
# 71: de - Accuracy: 69.0, Error Type: None
# 72: fruits - Accuracy: 1.0, Error Type: Mispronunciation
# 73: délicieux - Accuracy: 21.0, Error Type: Mispronunciation
# 74: chien - Accuracy: 11.0, Error Type: Mispronunciation
# 75: à - Accuracy: 94.0, Error Type: None
# 76: puces - Accuracy: 13.0, Error Type: Mispronunciation
# 77: a - Accuracy: 100.0, Error Type: Insertion
# 78: est - Accuracy: 0, Error Type: Omission
# 79: gourmand - Accuracy: 24.0, Error Type: Mispronunciation
# 80: il - Accuracy: 84.0, Error Type: None
# 81: croque - Accuracy: 37.0, Error Type: Mispronunciation
# 82: tout - Accuracy: 41.0, Error Type: Mispronunciation
# 83: ce - Accuracy: 80.0, Error Type: None
# 84: qui - Accuracy: 40.0, Error Type: Mispronunciation
# 85: lui - Accuracy: 90.0, Error Type: None
# 86: passe - Accuracy: 98.0, Error Type: None
# 87: sous - Accuracy: 100.0, Error Type: None
# 88: la - Accuracy: 94.0, Error Type: None
# 89: de - Accuracy: 82.0, Error Type: Insertion
# 90: le - Accuracy: 100.0, Error Type: Insertion
# 91: jour - Accuracy: 21.0, Error Type: Mispronunciation
# 92: choux - Accuracy: 68.0, Error Type: Insertion
# 93: y - Accuracy: 62.0, Error Type: Insertion
# 94: choux - Accuracy: 88.0, Error Type: Insertion
# 95: le - Accuracy: 80.0, Error Type: Insertion
# 96: dent - Accuracy: 0, Error Type: Omission
# 97: des - Accuracy: 0, Error Type: Omission
# 98: oranges - Accuracy: 0, Error Type: Omission
# 99: pourries - Accuracy: 0, Error Type: Omission
# 100: qui - Accuracy: 0, Error Type: Omission
# 101: tombent - Accuracy: 0, Error Type: Omission
# 102: sur - Accuracy: 82.0, Error Type: None
# 103: le - Accuracy: 0, Error Type: Omission
# 104: sol - Accuracy: 0, Error Type: Omission
# 105: des - Accuracy: 0, Error Type: Omission
# 106: fleurs - Accuracy: 36.0, Error Type: Mispronunciation
# 107: fanées - Accuracy: 7.0, Error Type: Mispronunciation
# 108: un - Accuracy: 58.0, Error Type: Mispronunciation
# 109: morceau - Accuracy: 49.0, Error Type: Mispronunciation
# 110: de - Accuracy: 67.0, Error Type: None
# 111: buvard - Accuracy: 17.0, Error Type: Mispronunciation
# 112: délicieux - Accuracy: 1.0, Error Type: Mispronunciation
# 113: un - Accuracy: 0, Error Type: Omission
# 114: jour - Accuracy: 22.0, Error Type: Mispronunciation
# 115: monsieur - Accuracy: 80.0, Error Type: None
# 116: petit - Accuracy: 23.0, Error Type: Mispronunciation
# 117: décide - Accuracy: 15.0, Error Type: Mispronunciation
# 118: de - Accuracy: 96.0, Error Type: None
# 119: mettre - Accuracy: 25.0, Error Type: Mispronunciation
# 120: chien - Accuracy: 0, Error Type: Omission
# 121: à - Accuracy: 0, Error Type: Omission
# 122: puces - Accuracy: 0, Error Type: Omission
# 123: dans - Accuracy: 0, Error Type: Omission
# 124: une - Accuracy: 0, Error Type: Omission
# 125: niche - Accuracy: 0, Error Type: Omission
# 126: chien - Accuracy: 0, Error Type: Omission
# 127: à - Accuracy: 0, Error Type: Omission
# 128: puces - Accuracy: 0, Error Type: Omission
# 129: n'aime - Accuracy: 0, Error Type: Omission
# 130: pas - Accuracy: 0, Error Type: Omission
# 131: être - Accuracy: 0, Error Type: Omission
# 132: enfermé - Accuracy: 0, Error Type: Omission
# 133: il - Accuracy: 0, Error Type: Omission
# 134: préfère - Accuracy: 0, Error Type: Omission
# 135: s'endormir - Accuracy: 0, Error Type: Omission
# 136: en - Accuracy: 0, Error Type: Omission
# 137: regardant - Accuracy: 0, Error Type: Omission
# 138: les - Accuracy: 0, Error Type: Omission
# 139: étoiles - Accuracy: 0, Error Type: Omission
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 38.16, Prosody: 0.00, Fluency: 53.25, Completeness: 26.36
# 1: se - Accuracy: 98.0, Error Type: Insertion
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 38.0, Error Type: Mispronunciation
# 4: de - Accuracy: 80.0, Error Type: None
# 5: monsieur - Accuracy: 29.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 90.0, Error Type: None
# 7: qui - Accuracy: 33.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 23.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 48.0, Error Type: Mispronunciation
# 10: une - Accuracy: 59.0, Error Type: Mispronunciation
# 11: vieille - Accuracy: 5.0, Error Type: Mispronunciation
# 12: maison - Accuracy: 50.0, Error Type: Mispronunciation
# 13: située - Accuracy: 49.0, Error Type: Mispronunciation
# 14: au - Accuracy: 49.0, Error Type: Mispronunciation
# 15: coeur - Accuracy: 53.0, Error Type: Mispronunciation
# 16: d'un - Accuracy: 15.0, Error Type: Mispronunciation
# 17: de - Accuracy: 96.0, Error Type: Insertion
# 18: vieux - Accuracy: 0, Error Type: Omission
# 19: village - Accuracy: 0, Error Type: Omission
# 20: la - Accuracy: 0, Error Type: Omission
# 21: maison - Accuracy: 0, Error Type: Omission
# 22: est - Accuracy: 0, Error Type: Omission
# 23: entourée - Accuracy: 0, Error Type: Omission
# 24: d'un - Accuracy: 0, Error Type: Omission
# 25: jardin - Accuracy: 0, Error Type: Omission
# 26: avec - Accuracy: 0, Error Type: Omission
# 27: une - Accuracy: 0, Error Type: Omission
# 28: barrière - Accuracy: 0, Error Type: Omission
# 29: il - Accuracy: 0, Error Type: Omission
# 30: y - Accuracy: 0, Error Type: Omission
# 31: a - Accuracy: 0, Error Type: Omission
# 32: des - Accuracy: 0, Error Type: Omission
# 33: concombres - Accuracy: 15.0, Error Type: Mispronunciation
# 34: des - Accuracy: 92.0, Error Type: None
# 35: choux - Accuracy: 88.0, Error Type: None
# 36: frisés - Accuracy: 24.0, Error Type: Mispronunciation
# 37: sol - Accuracy: 52.0, Error Type: Mispronunciation
# 38: toutes - Accuracy: 0, Error Type: Omission
# 39: sortes - Accuracy: 0, Error Type: Omission
# 40: de - Accuracy: 90.0, Error Type: None
# 41: légumes - Accuracy: 10.0, Error Type: Mispronunciation
# 42: au - Accuracy: 80.0, Error Type: None
# 43: fond - Accuracy: 48.0, Error Type: Mispronunciation
# 44: du - Accuracy: 80.0, Error Type: None
# 45: jardin - Accuracy: 37.0, Error Type: Mispronunciation
# 46: le - Accuracy: 88.0, Error Type: None
# 47: portillon - Accuracy: 12.0, Error Type: Mispronunciation
# 48: reste - Accuracy: 24.0, Error Type: Mispronunciation
# 49: toujours - Accuracy: 12.0, Error Type: Mispronunciation
# 50: fermé - Accuracy: 55.0, Error Type: Mispronunciation
# 51: pour - Accuracy: 20.0, Error Type: Mispronunciation
# 52: que - Accuracy: 13.0, Error Type: Mispronunciation
# 53: chien - Accuracy: 12.0, Error Type: Mispronunciation
# 54: à - Accuracy: 74.0, Error Type: None
# 55: puces - Accuracy: 15.0, Error Type: Mispronunciation
# 56: délicieux - Accuracy: 2.0, Error Type: Mispronunciation
# 57: ne - Accuracy: 90.0, Error Type: None
# 58: ne - Accuracy: 96.0, Error Type: Insertion
# 59: puces - Accuracy: 23.0, Error Type: Mispronunciation
# 60: s'échappe - Accuracy: 8.0, Error Type: Mispronunciation
# 61: pas - Accuracy: 72.0, Error Type: None
# 62: chien - Accuracy: 18.0, Error Type: Mispronunciation
# 63: à - Accuracy: 52.0, Error Type: Mispronunciation
# 64: puces - Accuracy: 21.0, Error Type: Mispronunciation
# 65: aime - Accuracy: 48.0, Error Type: Mispronunciation
# 66: se - Accuracy: 80.0, Error Type: None
# 67: coucher - Accuracy: 25.0, Error Type: Mispronunciation
# 68: près - Accuracy: 6.0, Error Type: Mispronunciation
# 69: de - Accuracy: 66.0, Error Type: None
# 70: la - Accuracy: 80.0, Error Type: None
# 71: poubelle - Accuracy: 61.0, Error Type: None
# 72: à - Accuracy: 96.0, Error Type: None
# 73: l'ombre - Accuracy: 57.0, Error Type: Mispronunciation
# 74: d'un - Accuracy: 80.0, Error Type: None
# 75: oranger - Accuracy: 0, Error Type: Omission
# 76: couvert - Accuracy: 33.0, Error Type: Mispronunciation
# 77: de - Accuracy: 94.0, Error Type: None
# 78: fruits - Accuracy: 2.0, Error Type: Mispronunciation
# 79: délicieux - Accuracy: 11.0, Error Type: Mispronunciation
# 80: chien - Accuracy: 32.0, Error Type: Mispronunciation
# 81: à - Accuracy: 96.0, Error Type: None
# 82: puces - Accuracy: 5.0, Error Type: Mispronunciation
# 83: est - Accuracy: 5.0, Error Type: Mispronunciation
# 84: gourmand - Accuracy: 31.0, Error Type: Mispronunciation
# 85: il - Accuracy: 72.0, Error Type: None
# 86: croque - Accuracy: 46.0, Error Type: Mispronunciation
# 87: tout - Accuracy: 45.0, Error Type: Mispronunciation
# 88: ce - Accuracy: 50.0, Error Type: Mispronunciation
# 89: qui - Accuracy: 5.0, Error Type: Mispronunciation
# 90: lui - Accuracy: 21.0, Error Type: Mispronunciation
# 91: passe - Accuracy: 98.0, Error Type: None
# 92: sous - Accuracy: 100.0, Error Type: None
# 93: la - Accuracy: 80.0, Error Type: None
# 94: dent - Accuracy: 7.0, Error Type: Mispronunciation
# 95: des - Accuracy: 68.0, Error Type: None
# 96: oranges - Accuracy: 8.0, Error Type: Mispronunciation
# 97: pourries - Accuracy: 5.0, Error Type: Mispronunciation
# 98: qui - Accuracy: 50.0, Error Type: Mispronunciation
# 99: tombent - Accuracy: 48.0, Error Type: Mispronunciation
# 100: sur - Accuracy: 54.0, Error Type: Mispronunciation
# 101: le - Accuracy: 80.0, Error Type: None
# 102: sol - Accuracy: 22.0, Error Type: Mispronunciation
# 103: des - Accuracy: 80.0, Error Type: None
# 104: fleurs - Accuracy: 27.0, Error Type: Mispronunciation
# 105: fanées - Accuracy: 15.0, Error Type: Mispronunciation
# 106: un - Accuracy: 80.0, Error Type: None
# 107: morceau - Accuracy: 52.0, Error Type: Mispronunciation
# 108: de - Accuracy: 0, Error Type: Omission
# 109: buvard - Accuracy: 40.0, Error Type: Mispronunciation
# 110: un - Accuracy: 80.0, Error Type: None
# 111: jour - Accuracy: 59.0, Error Type: Mispronunciation
# 112: monsieur - Accuracy: 56.0, Error Type: Mispronunciation
# 113: petit - Accuracy: 51.0, Error Type: Mispronunciation
# 114: décide - Accuracy: 10.0, Error Type: Mispronunciation
# 115: de - Accuracy: 96.0, Error Type: None
# 116: mettre - Accuracy: 51.0, Error Type: Mispronunciation
# 117: décide - Accuracy: 60.0, Error Type: Insertion
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 9.18, Prosody: 0.00, Fluency: 41.68, Completeness: 3.49
# 1: se - Accuracy: 88.0, Error Type: Insertion
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 50.0, Error Type: Mispronunciation
# 4: de - Accuracy: 80.0, Error Type: None
# 5: monsieur - Accuracy: 42.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 52.0, Error Type: Mispronunciation
# 7: qui - Accuracy: 8.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 11.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 12.0, Error Type: Mispronunciation
# 10: portillon - Accuracy: 11.0, Error Type: Mispronunciation
# 11: une - Accuracy: 0, Error Type: Omission
# 12: vieille - Accuracy: 0, Error Type: Omission
# 13: maison - Accuracy: 0, Error Type: Omission
# 14: située - Accuracy: 0, Error Type: Omission
# 15: au - Accuracy: 0, Error Type: Omission
# 16: coeur - Accuracy: 0, Error Type: Omission
# 17: d'un - Accuracy: 0, Error Type: Omission
# 18: vieux - Accuracy: 0, Error Type: Omission
# 19: village - Accuracy: 0, Error Type: Omission
# 20: la - Accuracy: 0, Error Type: Omission
# 21: maison - Accuracy: 0, Error Type: Omission
# 22: est - Accuracy: 0, Error Type: Omission
# 23: entourée - Accuracy: 0, Error Type: Omission
# 24: d'un - Accuracy: 0, Error Type: Omission
# 25: jardin - Accuracy: 0, Error Type: Omission
# 26: avec - Accuracy: 0, Error Type: Omission
# 27: une - Accuracy: 0, Error Type: Omission
# 28: barrière - Accuracy: 0, Error Type: Omission
# 29: il - Accuracy: 0, Error Type: Omission
# 30: y - Accuracy: 0, Error Type: Omission
# 31: a - Accuracy: 0, Error Type: Omission
# 32: des - Accuracy: 0, Error Type: Omission
# 33: concombres - Accuracy: 0, Error Type: Omission
# 34: des - Accuracy: 0, Error Type: Omission
# 35: choux - Accuracy: 0, Error Type: Omission
# 36: frisés - Accuracy: 0, Error Type: Omission
# 37: toutes - Accuracy: 0, Error Type: Omission
# 38: sortes - Accuracy: 0, Error Type: Omission
# 39: de - Accuracy: 0, Error Type: Omission
# 40: légumes - Accuracy: 0, Error Type: Omission
# 41: au - Accuracy: 0, Error Type: Omission
# 42: fond - Accuracy: 0, Error Type: Omission
# 43: du - Accuracy: 0, Error Type: Omission
# 44: jardin - Accuracy: 0, Error Type: Omission
# 45: le - Accuracy: 0, Error Type: Omission
# 46: portillon - Accuracy: 38.0, Error Type: Mispronunciation
# 47: reste - Accuracy: 78.0, Error Type: None
# 48: toujours - Accuracy: 12.0, Error Type: Mispronunciation
# 49: fermé - Accuracy: 26.0, Error Type: Mispronunciation
# 50: pour - Accuracy: 48.0, Error Type: Mispronunciation
# 51: choux - Accuracy: 18.0, Error Type: Mispronunciation
# 52: que - Accuracy: 0, Error Type: Omission
# 53: chien - Accuracy: 0, Error Type: Omission
# 54: à - Accuracy: 0, Error Type: Omission
# 55: puces - Accuracy: 0, Error Type: Omission
# 56: ne - Accuracy: 0, Error Type: Omission
# 57: s'échappe - Accuracy: 0, Error Type: Omission
# 58: pas - Accuracy: 0, Error Type: Omission
# 59: chien - Accuracy: 0, Error Type: Omission
# 60: à - Accuracy: 0, Error Type: Omission
# 61: puces - Accuracy: 0, Error Type: Omission
# 62: aime - Accuracy: 0, Error Type: Omission
# 63: se - Accuracy: 0, Error Type: Omission
# 64: coucher - Accuracy: 0, Error Type: Omission
# 65: près - Accuracy: 0, Error Type: Omission
# 66: de - Accuracy: 0, Error Type: Omission
# 67: la - Accuracy: 0, Error Type: Omission
# 68: poubelle - Accuracy: 0, Error Type: Omission
# 69: à - Accuracy: 0, Error Type: Omission
# 70: l'ombre - Accuracy: 0, Error Type: Omission
# 71: d'un - Accuracy: 0, Error Type: Omission
# 72: oranger - Accuracy: 0, Error Type: Omission
# 73: couvert - Accuracy: 27.0, Error Type: Mispronunciation
# 74: de - Accuracy: 0, Error Type: Omission
# 75: fruits - Accuracy: 0, Error Type: Omission
# 76: délicieux - Accuracy: 13.0, Error Type: Mispronunciation
# 77: choux - Accuracy: 50.0, Error Type: Mispronunciation
# 78: choux - Accuracy: 69.0, Error Type: Insertion
# 79: ce - Accuracy: 88.0, Error Type: Insertion
# 80: chien - Accuracy: 0, Error Type: Omission
# 81: à - Accuracy: 0, Error Type: Omission
# 82: puces - Accuracy: 0, Error Type: Omission
# 83: est - Accuracy: 0, Error Type: Omission
# 84: gourmand - Accuracy: 0, Error Type: Omission
# 85: il - Accuracy: 0, Error Type: Omission
# 86: croque - Accuracy: 11.0, Error Type: Mispronunciation
# 87: tout - Accuracy: 38.0, Error Type: Mispronunciation
# 88: ce - Accuracy: 66.0, Error Type: None
# 89: qui - Accuracy: 16.0, Error Type: Mispronunciation
# 90: lui - Accuracy: 18.0, Error Type: Mispronunciation
# 91: passe - Accuracy: 52.0, Error Type: Mispronunciation
# 92: sous - Accuracy: 40.0, Error Type: Mispronunciation
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 37.65, Prosody: 0.00, Fluency: 71.01, Completeness: 27.66
# 1: se - Accuracy: 98.0, Error Type: Insertion
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 18.0, Error Type: Mispronunciation
# 4: de - Accuracy: 80.0, Error Type: None
# 5: monsieur - Accuracy: 52.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 66.0, Error Type: None
# 7: qui - Accuracy: 25.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 35.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 32.0, Error Type: Mispronunciation
# 10: une - Accuracy: 22.0, Error Type: Mispronunciation
# 11: vieille - Accuracy: 4.0, Error Type: Mispronunciation
# 12: maison - Accuracy: 48.0, Error Type: Mispronunciation
# 13: située - Accuracy: 0, Error Type: Omission
# 14: au - Accuracy: 0, Error Type: Omission
# 15: coeur - Accuracy: 0, Error Type: Omission
# 16: d'un - Accuracy: 0, Error Type: Omission
# 17: vieux - Accuracy: 0, Error Type: Omission
# 18: village - Accuracy: 0, Error Type: Omission
# 19: la - Accuracy: 0, Error Type: Omission
# 20: maison - Accuracy: 0, Error Type: Omission
# 21: est - Accuracy: 0, Error Type: Omission
# 22: entourée - Accuracy: 0, Error Type: Omission
# 23: d'un - Accuracy: 0, Error Type: Omission
# 24: jardin - Accuracy: 0, Error Type: Omission
# 25: avec - Accuracy: 0, Error Type: Omission
# 26: une - Accuracy: 0, Error Type: Omission
# 27: barrière - Accuracy: 0, Error Type: Omission
# 28: il - Accuracy: 98.0, Error Type: None
# 29: y - Accuracy: 86.0, Error Type: None
# 30: a - Accuracy: 100.0, Error Type: None
# 31: des - Accuracy: 80.0, Error Type: None
# 32: concombres - Accuracy: 13.0, Error Type: Mispronunciation
# 33: des - Accuracy: 42.0, Error Type: Mispronunciation
# 34: choux - Accuracy: 84.0, Error Type: None
# 35: frisés - Accuracy: 19.0, Error Type: Mispronunciation
# 36: toutes - Accuracy: 48.0, Error Type: Mispronunciation
# 37: sortes - Accuracy: 21.0, Error Type: Mispronunciation
# 38: de - Accuracy: 82.0, Error Type: None
# 39: légumes - Accuracy: 15.0, Error Type: Mispronunciation
# 40: au - Accuracy: 80.0, Error Type: None
# 41: fond - Accuracy: 56.0, Error Type: Mispronunciation
# 42: du - Accuracy: 94.0, Error Type: None
# 43: jardin - Accuracy: 5.0, Error Type: Mispronunciation
# 44: de - Accuracy: 51.0, Error Type: Mispronunciation
# 45: le - Accuracy: 98.0, Error Type: None
# 46: portillon - Accuracy: 45.0, Error Type: Mispronunciation
# 47: reste - Accuracy: 96.0, Error Type: None
# 48: toujours - Accuracy: 11.0, Error Type: Mispronunciation
# 49: fermé - Accuracy: 40.0, Error Type: Mispronunciation
# 50: pour - Accuracy: 90.0, Error Type: None
# 51: que - Accuracy: 24.0, Error Type: Mispronunciation
# 52: sur - Accuracy: 30.0, Error Type: Mispronunciation
# 53: chien - Accuracy: 0, Error Type: Omission
# 54: à - Accuracy: 100.0, Error Type: None
# 55: puces - Accuracy: 45.0, Error Type: Mispronunciation
# 56: ne - Accuracy: 88.0, Error Type: None
# 57: sur - Accuracy: 49.0, Error Type: Mispronunciation
# 58: s'échappe - Accuracy: 50.0, Error Type: Mispronunciation
# 59: pas - Accuracy: 88.0, Error Type: None
# 60: sur - Accuracy: 45.0, Error Type: Mispronunciation
# 61: chien - Accuracy: 0, Error Type: Omission
# 62: à - Accuracy: 98.0, Error Type: None
# 63: monsieur - Accuracy: 16.0, Error Type: Mispronunciation
# 64: coeur - Accuracy: 55.0, Error Type: Mispronunciation
# 65: choux - Accuracy: 42.0, Error Type: Mispronunciation
# 66: puces - Accuracy: 0, Error Type: Omission
# 67: aime - Accuracy: 0, Error Type: Omission
# 68: se - Accuracy: 0, Error Type: Omission
# 69: coucher - Accuracy: 0, Error Type: Omission
# 70: près - Accuracy: 90.0, Error Type: None
# 71: de - Accuracy: 88.0, Error Type: None
# 72: la - Accuracy: 100.0, Error Type: None
# 73: poubelle - Accuracy: 98.0, Error Type: None
# 74: à - Accuracy: 98.0, Error Type: None
# 75: l'ombre - Accuracy: 43.0, Error Type: Mispronunciation
# 76: d'un - Accuracy: 32.0, Error Type: Mispronunciation
# 77: oranger - Accuracy: 0, Error Type: Omission
# 78: couvert - Accuracy: 45.0, Error Type: Mispronunciation
# 79: de - Accuracy: 98.0, Error Type: None
# 80: fruits - Accuracy: 1.0, Error Type: Mispronunciation
# 81: délicieux - Accuracy: 53.0, Error Type: Mispronunciation
# 82: chien - Accuracy: 22.0, Error Type: Mispronunciation
# 83: à - Accuracy: 43.0, Error Type: Mispronunciation
# 84: puces - Accuracy: 15.0, Error Type: Mispronunciation
# 85: a - Accuracy: 100.0, Error Type: Insertion
# 86: est - Accuracy: 0, Error Type: Omission
# 87: gourmand - Accuracy: 23.0, Error Type: Mispronunciation
# 88: il - Accuracy: 80.0, Error Type: None
# 89: croque - Accuracy: 17.0, Error Type: Mispronunciation
# 90: tout - Accuracy: 53.0, Error Type: Mispronunciation
# 91: choux - Accuracy: 74.0, Error Type: Insertion
# 92: ce - Accuracy: 0, Error Type: Omission
# 93: qui - Accuracy: 0, Error Type: Omission
# 94: lui - Accuracy: 5.0, Error Type: Mispronunciation
# 95: passe - Accuracy: 52.0, Error Type: Mispronunciation
# 96: sous - Accuracy: 96.0, Error Type: None
# 97: la - Accuracy: 100.0, Error Type: None
# 98: dans - Accuracy: 29.0, Error Type: Mispronunciation
# 99: toujours - Accuracy: 2.0, Error Type: Mispronunciation
# 100: dent - Accuracy: 0, Error Type: Omission
# 101: des - Accuracy: 0, Error Type: Omission
# 102: oranges - Accuracy: 0, Error Type: Omission
# 103: pourries - Accuracy: 30.0, Error Type: Mispronunciation
# 104: qui - Accuracy: 50.0, Error Type: Mispronunciation
# 105: tombent - Accuracy: 28.0, Error Type: Mispronunciation
# 106: sur - Accuracy: 21.0, Error Type: Mispronunciation
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 21.98, Prosody: 0.00, Fluency: 45.09, Completeness: 11.48
# 1: c'est - Accuracy: 0, Error Type: Omission
# 2: l'histoire - Accuracy: 32.0, Error Type: Mispronunciation
# 3: de - Accuracy: 74.0, Error Type: None
# 4: monsieur - Accuracy: 32.0, Error Type: Mispronunciation
# 5: petit - Accuracy: 39.0, Error Type: Mispronunciation
# 6: qui - Accuracy: 16.0, Error Type: Mispronunciation
# 7: vit - Accuracy: 6.0, Error Type: Mispronunciation
# 8: dans - Accuracy: 17.0, Error Type: Mispronunciation
# 9: une - Accuracy: 9.0, Error Type: Mispronunciation
# 10: vieille - Accuracy: 6.0, Error Type: Mispronunciation
# 11: maison - Accuracy: 42.0, Error Type: Mispronunciation
# 12: située - Accuracy: 43.0, Error Type: Mispronunciation
# 13: au - Accuracy: 49.0, Error Type: Mispronunciation
# 14: coeur - Accuracy: 0, Error Type: Omission
# 15: d'un - Accuracy: 8.0, Error Type: Mispronunciation
# 16: vieux - Accuracy: 80.0, Error Type: None
# 17: village - Accuracy: 34.0, Error Type: Mispronunciation
# 18: la - Accuracy: 80.0, Error Type: None
# 19: maison - Accuracy: 55.0, Error Type: Mispronunciation
# 20: est - Accuracy: 0, Error Type: Omission
# 21: entourée - Accuracy: 0, Error Type: Omission
# 22: d'un - Accuracy: 0, Error Type: Omission
# 23: jardin - Accuracy: 0, Error Type: Omission
# 24: avec - Accuracy: 0, Error Type: Omission
# 25: une - Accuracy: 0, Error Type: Omission
# 26: barrière - Accuracy: 0, Error Type: Omission
# 27: il - Accuracy: 0, Error Type: Omission
# 28: y - Accuracy: 0, Error Type: Omission
# 29: a - Accuracy: 98.0, Error Type: None
# 30: des - Accuracy: 0, Error Type: Omission
# 31: concombres - Accuracy: 0, Error Type: Omission
# 32: des - Accuracy: 53.0, Error Type: Mispronunciation
# 33: choux - Accuracy: 48.0, Error Type: Mispronunciation
# 34: frisés - Accuracy: 18.0, Error Type: Mispronunciation
# 35: toutes - Accuracy: 48.0, Error Type: Mispronunciation
# 36: choux - Accuracy: 54.0, Error Type: Mispronunciation
# 37: sortes - Accuracy: 0, Error Type: Omission
# 38: de - Accuracy: 0, Error Type: Omission
# 39: légumes - Accuracy: 0, Error Type: Omission
# 40: au - Accuracy: 0, Error Type: Omission
# 41: fond - Accuracy: 0, Error Type: Omission
# 42: du - Accuracy: 0, Error Type: Omission
# 43: jardin - Accuracy: 0, Error Type: Omission
# 44: le - Accuracy: 0, Error Type: Omission
# 45: portillon - Accuracy: 0, Error Type: Omission
# 46: reste - Accuracy: 0, Error Type: Omission
# 47: toujours - Accuracy: 0, Error Type: Omission
# 48: fermé - Accuracy: 0, Error Type: Omission
# 49: pour - Accuracy: 0, Error Type: Omission
# 50: que - Accuracy: 0, Error Type: Omission
# 51: chien - Accuracy: 0, Error Type: Omission
# 52: à - Accuracy: 84.0, Error Type: None
# 53: puces - Accuracy: 15.0, Error Type: Mispronunciation
# 54: ne - Accuracy: 11.0, Error Type: Mispronunciation
# 55: s'échappe - Accuracy: 18.0, Error Type: Mispronunciation
# 56: pas - Accuracy: 53.0, Error Type: Mispronunciation
# 57: que - Accuracy: 51.0, Error Type: Mispronunciation
# 58: chien - Accuracy: 0, Error Type: Omission
# 59: à - Accuracy: 98.0, Error Type: None
# 60: puces - Accuracy: 14.0, Error Type: Mispronunciation
# 61: aime - Accuracy: 69.0, Error Type: None
# 62: y - Accuracy: 76.0, Error Type: Insertion
# 63: choux - Accuracy: 52.0, Error Type: Mispronunciation
# 64: coeur - Accuracy: 30.0, Error Type: Mispronunciation
# 65: choux - Accuracy: 15.0, Error Type: Mispronunciation
# 66: se - Accuracy: 0, Error Type: Omission
# 67: coucher - Accuracy: 0, Error Type: Omission
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 32.02, Prosody: 0.00, Fluency: 61.24, Completeness: 20.00
# 1: c'est - Accuracy: 9.0, Error Type: Mispronunciation
# 2: l'histoire - Accuracy: 22.0, Error Type: Mispronunciation
# 3: de - Accuracy: 38.0, Error Type: Mispronunciation
# 4: monsieur - Accuracy: 26.0, Error Type: Mispronunciation
# 5: petit - Accuracy: 70.0, Error Type: None
# 6: qui - Accuracy: 27.0, Error Type: Mispronunciation
# 7: vit - Accuracy: 35.0, Error Type: Mispronunciation
# 8: dans - Accuracy: 14.0, Error Type: Mispronunciation
# 9: une - Accuracy: 8.0, Error Type: Mispronunciation
# 10: vieille - Accuracy: 10.0, Error Type: Mispronunciation
# 11: maison - Accuracy: 48.0, Error Type: Mispronunciation
# 12: située - Accuracy: 48.0, Error Type: Mispronunciation
# 13: au - Accuracy: 94.0, Error Type: None
# 14: coeur - Accuracy: 40.0, Error Type: Mispronunciation
# 15: d'un - Accuracy: 14.0, Error Type: Mispronunciation
# 16: vieux - Accuracy: 38.0, Error Type: Mispronunciation
# 17: village - Accuracy: 45.0, Error Type: Mispronunciation
# 18: la - Accuracy: 53.0, Error Type: Mispronunciation
# 19: maison - Accuracy: 46.0, Error Type: Mispronunciation
# 20: est - Accuracy: 0, Error Type: Omission
# 21: entourée - Accuracy: 0, Error Type: Omission
# 22: d'un - Accuracy: 0, Error Type: Omission
# 23: jardin - Accuracy: 0, Error Type: Omission
# 24: avec - Accuracy: 0, Error Type: Omission
# 25: une - Accuracy: 0, Error Type: Omission
# 26: barrière - Accuracy: 0, Error Type: Omission
# 27: il - Accuracy: 0, Error Type: Omission
# 28: y - Accuracy: 0, Error Type: Omission
# 29: a - Accuracy: 0, Error Type: Omission
# 30: des - Accuracy: 0, Error Type: Omission
# 31: concombres - Accuracy: 8.0, Error Type: Mispronunciation
# 32: des - Accuracy: 80.0, Error Type: None
# 33: choux - Accuracy: 58.0, Error Type: Mispronunciation
# 34: frisés - Accuracy: 17.0, Error Type: Mispronunciation
# 35: toutes - Accuracy: 76.0, Error Type: None
# 36: sortes - Accuracy: 8.0, Error Type: Mispronunciation
# 37: de - Accuracy: 98.0, Error Type: None
# 38: légumes - Accuracy: 15.0, Error Type: Mispronunciation
# 39: au - Accuracy: 82.0, Error Type: None
# 40: fond - Accuracy: 8.0, Error Type: Mispronunciation
# 41: du - Accuracy: 73.0, Error Type: None
# 42: jardin - Accuracy: 25.0, Error Type: Mispronunciation
# 43: le - Accuracy: 48.0, Error Type: Mispronunciation
# 44: pas - Accuracy: 48.0, Error Type: Mispronunciation
# 45: portillon - Accuracy: 0, Error Type: Omission
# 46: reste - Accuracy: 29.0, Error Type: Mispronunciation
# 47: toujours - Accuracy: 32.0, Error Type: Mispronunciation
# 48: fermé - Accuracy: 49.0, Error Type: Mispronunciation
# 49: délicieux - Accuracy: 12.0, Error Type: Mispronunciation
# 50: pour - Accuracy: 0, Error Type: Omission
# 51: que - Accuracy: 0, Error Type: Omission
# 52: chien - Accuracy: 0, Error Type: Omission
# 53: à - Accuracy: 78.0, Error Type: None
# 54: puces - Accuracy: 18.0, Error Type: Mispronunciation
# 55: ne - Accuracy: 23.0, Error Type: Mispronunciation
# 56: s'échappe - Accuracy: 44.0, Error Type: Mispronunciation
# 57: choux - Accuracy: 68.0, Error Type: Insertion
# 58: pas - Accuracy: 0, Error Type: Omission
# 59: chien - Accuracy: 0, Error Type: Omission
# 60: à - Accuracy: 58.0, Error Type: Mispronunciation
# 61: puces - Accuracy: 16.0, Error Type: Mispronunciation
# 62: aime - Accuracy: 47.0, Error Type: Mispronunciation
# 63: se - Accuracy: 80.0, Error Type: None
# 64: coucher - Accuracy: 20.0, Error Type: Mispronunciation
# 65: près - Accuracy: 11.0, Error Type: Mispronunciation
# 66: de - Accuracy: 84.0, Error Type: None
# 67: la - Accuracy: 98.0, Error Type: None
# 68: poubelle - Accuracy: 80.0, Error Type: None
# 69: à - Accuracy: 0, Error Type: Omission
# 70: l'ombre - Accuracy: 0, Error Type: Omission
# 71: d'un - Accuracy: 0, Error Type: Omission
# 72: oranger - Accuracy: 0, Error Type: Omission
# 73: couvert - Accuracy: 0, Error Type: Omission
# 74: de - Accuracy: 65.0, Error Type: None
# 75: fruits - Accuracy: 2.0, Error Type: Mispronunciation
# 76: délicieux - Accuracy: 52.0, Error Type: Mispronunciation
# 77: qui - Accuracy: 54.0, Error Type: Mispronunciation
# 78: chien - Accuracy: 0, Error Type: Omission
# 79: à - Accuracy: 100.0, Error Type: None
# 80: près - Accuracy: 52.0, Error Type: Mispronunciation
# 81: a - Accuracy: 100.0, Error Type: Insertion
# 82: puces - Accuracy: 0, Error Type: Omission
# 83: est - Accuracy: 0, Error Type: Omission
# 84: gourmand - Accuracy: 22.0, Error Type: Mispronunciation
# 85: il - Accuracy: 76.0, Error Type: None
# 86: croque - Accuracy: 27.0, Error Type: Mispronunciation
# 87: tout - Accuracy: 17.0, Error Type: Mispronunciation
# 88: ce - Accuracy: 76.0, Error Type: None
# 89: qui - Accuracy: 24.0, Error Type: Mispronunciation
# 90: lui - Accuracy: 27.0, Error Type: Mispronunciation
# 91: passe - Accuracy: 84.0, Error Type: None
# 92: ce - Accuracy: 88.0, Error Type: Insertion
# 93: la - Accuracy: 76.0, Error Type: Insertion
# 94: dans - Accuracy: 52.0, Error Type: Mispronunciation
# 95: pour - Accuracy: 22.0, Error Type: Mispronunciation
# 96: y - Accuracy: 45.0, Error Type: Mispronunciation
# 97: d'un - Accuracy: 54.0, Error Type: Mispronunciation
# 98: y - Accuracy: 54.0, Error Type: Mispronunciation
# 99: monsieur - Accuracy: 29.0, Error Type: Mispronunciation
# 100: de - Accuracy: 76.0, Error Type: Insertion
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# Accuracy: 30.94, Prosody: 0.00, Fluency: 61.15, Completeness: 13.11
# 1: se - Accuracy: 51.0, Error Type: Mispronunciation
# 2: c'est - Accuracy: 0, Error Type: Omission
# 3: l'histoire - Accuracy: 14.0, Error Type: Mispronunciation
# 4: de - Accuracy: 52.0, Error Type: Mispronunciation
# 5: monsieur - Accuracy: 28.0, Error Type: Mispronunciation
# 6: petit - Accuracy: 49.0, Error Type: Mispronunciation
# 7: qui - Accuracy: 28.0, Error Type: Mispronunciation
# 8: vit - Accuracy: 27.0, Error Type: Mispronunciation
# 9: dans - Accuracy: 10.0, Error Type: Mispronunciation
# 10: une - Accuracy: 14.0, Error Type: Mispronunciation
# 11: vieille - Accuracy: 5.0, Error Type: Mispronunciation
# 12: maison - Accuracy: 51.0, Error Type: Mispronunciation
# 13: située - Accuracy: 50.0, Error Type: Mispronunciation
# 14: au - Accuracy: 0, Error Type: Omission
# 15: coeur - Accuracy: 0, Error Type: Omission
# 16: d'un - Accuracy: 48.0, Error Type: Mispronunciation
# 17: vieux - Accuracy: 96.0, Error Type: None
# 18: village - Accuracy: 50.0, Error Type: Mispronunciation
# 19: la - Accuracy: 100.0, Error Type: None
# 20: maison - Accuracy: 57.0, Error Type: Mispronunciation
# 21: a - Accuracy: 98.0, Error Type: Insertion
# 22: est - Accuracy: 0, Error Type: Omission
# 23: entourée - Accuracy: 26.0, Error Type: Mispronunciation
# 24: d'un - Accuracy: 51.0, Error Type: Mispronunciation
# 25: jardin - Accuracy: 30.0, Error Type: Mispronunciation
# 26: avec - Accuracy: 0, Error Type: Omission
# 27: une - Accuracy: 0, Error Type: Omission
# 28: barrière - Accuracy: 0, Error Type: Omission
# 29: il - Accuracy: 80.0, Error Type: None
# 30: y - Accuracy: 54.0, Error Type: Mispronunciation
# 31: a - Accuracy: 98.0, Error Type: None
# 32: des - Accuracy: 42.0, Error Type: Mispronunciation
# 33: concombres - Accuracy: 0, Error Type: Omission
# 34: des - Accuracy: 20.0, Error Type: Mispronunciation
# 35: choux - Accuracy: 34.0, Error Type: Mispronunciation
# 36: frisés - Accuracy: 22.0, Error Type: Mispronunciation
# 37: toutes - Accuracy: 48.0, Error Type: Mispronunciation
# 38: sortes - Accuracy: 7.0, Error Type: Mispronunciation
# 39: de - Accuracy: 98.0, Error Type: None
# 40: légumes - Accuracy: 5.0, Error Type: Mispronunciation
# 41: pour - Accuracy: 53.0, Error Type: Mispronunciation
# 42: au - Accuracy: 0, Error Type: Omission
# 43: fond - Accuracy: 0, Error Type: Omission
# 44: du - Accuracy: 41.0, Error Type: Mispronunciation
# 45: jardin - Accuracy: 0, Error Type: Omission
# 46: le - Accuracy: 0, Error Type: Omission
# 47: portillon - Accuracy: 0, Error Type: Omission
# 48: reste - Accuracy: 48.0, Error Type: Mispronunciation
# 49: toujours - Accuracy: 0, Error Type: Omission
# 50: fermé - Accuracy: 0, Error Type: Omission
# 51: pour - Accuracy: 58.0, Error Type: Mispronunciation
# 52: que - Accuracy: 50.0, Error Type: Mispronunciation
# 53: choux - Accuracy: 63.0, Error Type: Insertion
# 54: chien - Accuracy: 0, Error Type: Omission
# 55: à - Accuracy: 56.0, Error Type: Mispronunciation
# 56: puces - Accuracy: 20.0, Error Type: Mispronunciation
# 57: ne - Accuracy: 0, Error Type: Omission
# 58: s'échappe - Accuracy: 5.0, Error Type: Mispronunciation
# 59: pas - Accuracy: 72.0, Error Type: None
# 60: choux - Accuracy: 45.0, Error Type: Mispronunciation
# 61: il - Accuracy: 98.0, Error Type: Insertion
# 62: chien - Accuracy: 0, Error Type: Omission
# 63: à - Accuracy: 92.0, Error Type: None
# 64: puces - Accuracy: 20.0, Error Type: Mispronunciation
# 65: aime - Accuracy: 84.0, Error Type: None
# 66: choux - Accuracy: 98.0, Error Type: Insertion
# 67: du - Accuracy: 96.0, Error Type: Insertion
# 68: choux - Accuracy: 22.0, Error Type: Mispronunciation
# 69: se - Accuracy: 0, Error Type: Omission
# 70: coucher - Accuracy: 0, Error Type: Omission
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: received close frame, sending a close response frame.
# Info: on_underlying_io_close_sent: uws_client=0x125e31b90, io_send_result:0
# Info: on_underlying_io_close_sent: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.

# %% [markdown]
# ## AZURE model without the reference text

# %%
def assess_pronunciation_continuous(audio_file: str):
    """Performs continuous pronunciation assessment for a long audio file without requiring a reference text."""
    
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    audio_config = speechsdk.audio.AudioConfig(filename=audio_file)

    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, language="en-US", audio_config=audio_config)

    done = False
    recognized_words = []
    prosody_scores = []
    fluency_scores = []
    durations = []

    def stop_cb(evt: speechsdk.SessionEventArgs):
        """Stops the recognition process"""
        nonlocal done
        done = True

    def recognized(evt: speechsdk.SpeechRecognitionEventArgs):
        """Handles recognized speech"""
        pronunciation_result = speechsdk.PronunciationAssessmentResult(evt.result)
        recognized_words.extend(pronunciation_result.words)
        fluency_scores.append(pronunciation_result.fluency_score)
        if pronunciation_result.prosody_score is not None:
            prosody_scores.append(pronunciation_result.prosody_score)
        json_result = evt.result.properties.get(speechsdk.PropertyId.SpeechServiceResponse_JsonResult)
        jo = json.loads(json_result)
        nb = jo["NBest"][0]
        durations.append(sum([int(w["Duration"]) for w in nb["Words"]]))

    # Attach event handlers
    speech_recognizer.recognized.connect(recognized)
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(0.5)
    
    speech_recognizer.stop_continuous_recognition()

    # Calculate final scores
    accuracy_scores = [word.accuracy_score for word in recognized_words if word.error_type != 'Insertion']
    accuracy_score = sum(accuracy_scores) / len(accuracy_scores) if accuracy_scores else 0
    prosody_score = sum(prosody_scores) / len(prosody_scores) if prosody_scores else 0
    fluency_score = sum([x * y for (x, y) in zip(fluency_scores, durations)]) / sum(durations) if durations else 0

    # Print results
    print(f'Accuracy: {accuracy_score:.2f}, Prosody: {prosody_score:.2f}, Fluency: {fluency_score:.2f}')
    for idx, word in enumerate(recognized_words):
        print(f'{idx + 1}: {word.word} - Accuracy: {word.accuracy_score}, Error Type: {word.error_type}')

# %%
tests_id = [
    '2BB671AA-2F6A-4346-8B76-F0C89C236390',
    '3B545E56-D802-4380-9993-21C11066B12E',
    '5C1C826F-E778-48C3-9170-6BF943175984',
    '046E4FEB-E284-48D5-922E-616DA7651F02',
    '75A80925-F8CF-463D-AFED-5CC399848CC2',
    '102DCD09-43EA-434D-A590-0FA5C7C7C1B3',
    '098522E8-2203-425E-85E5-5809D5B0B523',
    '79055215-1979-42D3-9B26-B9C6DD935D83',
    'ABD81BE7-7629-4816-8241-7ECBF32DFFFA',
]

# We iterate over the tests_id and we evaluate each one
for test_id in tests_id:
    audio_file = f"sample_readingTestFluencE/readingTestFluencE_{test_id}.wav"

    print('=' * 60)
    assess_pronunciation_continuous(audio_file=audio_file)
# Out:
# ============================================================
# Accuracy: 0.00, Prosody: 0.00, Fluency: 0.00
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# ============================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 18
#      15 audio_file = f"sample_readingTestFluencE/readingTestFluencE_{test_id}.wav"
#      17 print('=' * 60)
# ---> 18 assess_pronunciation_continuous(audio_file=audio_file)
#
# Cell In[10], line 40, in assess_pronunciation_continuous(audio_file)
#      38 speech_recognizer.start_continuous_recognition()
#      39 while not done:
# ---> 40     time.sleep(0.5)
#      42 speech_recognizer.stop_continuous_recognition()
#      44 # Calculate final scores
#
# KeyboardInterrupt:
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: received close frame, sending a close response frame.
# Info: on_underlying_io_close_sent: uws_client=0x1479eadb0, io_send_result:0
# Info: on_underlying_io_close_sent: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: received close frame, sending a close response frame.
# Info: on_underlying_io_close_sent: uws_client=0x1479ef970, io_send_result:0
# Info: on_underlying_io_close_sent: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: received close frame, sending a close response frame.
# Info: on_underlying_io_close_sent: uws_client=0x106909a40, io_send_result:0
# Info: on_underlying_io_close_sent: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.
