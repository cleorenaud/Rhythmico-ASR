# %%
import os
import ast
import torch
from transformers import AutoModelForCTC, Wav2Vec2Processor
import numpy as np
import pandas as pd
import soundfile as sf
from src.text_processing import *
from src.data_processing import *
from src.ui_tools import *
from src.audio_processing import *

# Add espeak's shared library directory
os.environ['DYLD_LIBRARY_PATH'] = '/opt/homebrew/lib'

# %%
# Load the cleaned data
data_path = 'data/df_test_cleaned.csv'
tests_df = pd.read_csv(data_path)

# We only keep the rows where the testType is testPhoneme
phonemeTest_df = tests_df[tests_df['testType'] == 'testPhoneme']

# Apply conversion functions to testResults and evaluationResults columns
phonemeTest_df['testResults'] = phonemeTest_df['testResults'].apply(lambda x: convert_str_to_dct_eval(x))
phonemeTest_df['evaluationResults'] = phonemeTest_df['evaluationResults'].apply(lambda x: convert_str_to_dct_eval(x))
# Out:
# /var/folders/kn/xrv1vh8j0k99dnh2mwl662xc0000gn/T/ipykernel_5801/1745748040.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phonemeTest_df['testResults'] = phonemeTest_df['testResults'].apply(lambda x: convert_str_to_dct_eval(x))
# /var/folders/kn/xrv1vh8j0k99dnh2mwl662xc0000gn/T/ipykernel_5801/1745748040.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phonemeTest_df['evaluationResults'] = phonemeTest_df['evaluationResults'].apply(lambda x: convert_str_to_dct_eval(x))

# %%
save_recordings_as_wav(phonemeTest_df, output_dir='wav_files/testPhoneme', target_sample_rate=16000, channels=1)

# %%
# The groundtruth labels for the deletion phoneme test
deletion = 'vert rame lou ane reine dine lo rou li rose'

# The groundtruth labels for the fusion phoneme test
fusion = 'fa cha bou ten boi cho gué quin jin gren'

# %%
# If the transcription files already exist, we do nothing
deletion_file = 'testPhoneme_deletion_transcriptions.csv'
fusion_file = 'testPhoneme_fusion_transcriptions.csv'
files_exist = (os.path.isfile(deletion_file) or os.path.isfile(fusion_file))

if not(files_exist):
    # We save the groundtruth labels to a csv file
    save_phonetic_transcription_to_csv(deletion, test_type='testPhoneme', folder='transcriptions', file_name=deletion_file)
    save_phonetic_transcription_to_csv(fusion, test_type='testPhoneme', folder='transcriptions', file_name=fusion_file)
# Out:
# Phonetic transcription saved to transcriptions/testPhoneme_deletion_transcriptions.csv
# Phonetic transcription saved to transcriptions/testPhoneme_fusion_transcriptions.csv

# %%
# Initialize the model and processor
MODEL_ID = "Cnam-LMSSC/wav2vec2-french-phonemizer"
model = AutoModelForCTC.from_pretrained(MODEL_ID)
processor = Wav2Vec2Processor.from_pretrained(MODEL_ID)

# %%
# Folder containing the audio files
audio_folder = 'wav_files/testPhoneme/'
output_csv = 'transcriptions/testPhoneme_children.csv'

# List all the .wav files in the folder
audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.wav')]

# Check if the CSV file already exists to write the header only once
file_exists = os.path.isfile(output_csv)

# Open the CSV in append mode
with open(output_csv, mode='a', encoding='utf-8', newline='') as f:
    # CSV writer setup
    import csv
    writer = csv.writer(f)
    
    # Write header if the file doesn't exist yet
    if not file_exists:
        writer.writerow(['File Name', 'Phonetic Transcription'])
    
    # Process each file one by one
    for audio_file in audio_files:
        try:
            # Load the audio file
            audio_path = os.path.join(audio_folder, audio_file)
            audio, sr = sf.read(audio_path)

            # Ensure audio is in the correct format (mono and float32)
            audio = np.array(audio, dtype=np.float32)
            
            # Preprocess the audio and prepare the inputs for the model
            inputs = processor(audio, sampling_rate=16_000, return_tensors="pt")

            # Get the model's predictions
            with torch.no_grad():
                logits = model(**inputs).logits

            # Decode the predictions to get the phonetic transcription
            predicted_ids = torch.argmax(logits, dim=-1)
            transcription = processor.batch_decode(predicted_ids)[0]

            # Write the current result as a new line in the CSV
            writer.writerow([audio_file, transcription])

            # Optional: print progress
            print(f"Processed and saved transcription for: {audio_file}")

        except Exception as e:
            print(f"Error processing {audio_file}: {e}")
# Out:
# Processed and saved transcription for: testPhoneme_A80E6D01-D6C8-4E73-BCA0-77F29AF6DDB2.wav
# Processed and saved transcription for: testPhoneme_233DA148-5EF9-4177-B538-54AC75D8AF55.wav
# Processed and saved transcription for: testPhoneme_B8BB10DA-9B28-4538-BF07-35BA94AE5FE4.wav
# Processed and saved transcription for: testPhoneme_EAC0BB7F-8195-4697-8BF1-1B979D198195.wav
# Processed and saved transcription for: testPhoneme_31C2AB2C-D941-42C6-A0B3-862AEB09290D.wav
# Processed and saved transcription for: testPhoneme_1F1DE99C-28B1-494E-AE86-9BC17D80753A.wav
# Processed and saved transcription for: testPhoneme_1790F47F-D746-49C7-BD87-EADAF043A5A6.wav
# Processed and saved transcription for: testPhoneme_2095B05B-E764-436C-8B53-48A734740FF6.wav
# Processed and saved transcription for: testPhoneme_708E3AD2-8746-4218-86B2-54668105CA29.wav
# Processed and saved transcription for: testPhoneme_97AF3CF5-7048-4725-A3CA-6F6676140F15.wav
# Processed and saved transcription for: testPhoneme_2A4B2BB2-62FA-4AA6-9BD8-A672B2BC8FA4.wav
# Processed and saved transcription for: testPhoneme_AB5B9A69-EF6F-47A3-9A03-ADB549AC48BF.wav
# Processed and saved transcription for: testPhoneme_021989E7-E08B-4FE2-92A4-776EB2E0CB60.wav
# Processed and saved transcription for: testPhoneme_A124CF2C-FF86-4426-BDDF-5444F2EFDD27.wav
# Processed and saved transcription for: testPhoneme_1EA07D86-1276-4775-88D6-9C3C09FB0F6C.wav
# Processed and saved transcription for: testPhoneme_724F3630-96CB-4ACE-838C-2BD7F4DDC750.wav
# Processed and saved transcription for: testPhoneme_550CB8EB-1246-4F7F-87AD-4AE6BA097F67.wav
# Processed and saved transcription for: testPhoneme_F17BE1DB-0236-4912-951C-22099972B229.wav
# Processed and saved transcription for: testPhoneme_58AFD282-73BF-4C47-B2EC-D7E4E4751F76.wav
# Processed and saved transcription for: testPhoneme_B89A0863-CA7F-4BA1-A1D7-EB1D917ECD7F.wav
# Processed and saved transcription for: testPhoneme_E74E0468-70A6-401B-84F2-D028E7C2A50A.wav
# Processed and saved transcription for: testPhoneme_16D4DD99-53BD-43AC-83B5-E09D86FEC3A9.wav
# Processed and saved transcription for: testPhoneme_34B758E2-D862-41BB-BCD5-5B449047C617.wav
# Processed and saved transcription for: testPhoneme_C25C735A-F8BE-4D6F-90E7-A301A78961CF.wav
# Processed and saved transcription for: testPhoneme_BF0F9FA3-F553-4926-BA4A-E3157C79CBF6.wav
# Processed and saved transcription for: testPhoneme_14E99059-AF86-42C4-9EF3-0296CDE08EEF.wav
# Processed and saved transcription for: testPhoneme_60AB5E25-D217-45DA-91CB-2D8F127E4657.wav
# Processed and saved transcription for: testPhoneme_FF0FADD4-813B-40AC-9749-B8FD2A34319D.wav
# Processed and saved transcription for: testPhoneme_2D374096-CBA5-4D59-B3FD-7A80A78116BB.wav
# Processed and saved transcription for: testPhoneme_18DB4B33-ED30-4BA1-9B2A-F4FDF53E4B1D.wav
# Processed and saved transcription for: testPhoneme_CACE0B90-F8DC-4E4D-9F12-1D41E2FE2DF3.wav
# Processed and saved transcription for: testPhoneme_19F0E29C-D30B-4ABA-9EED-63E068D7730F.wav
# Processed and saved transcription for: testPhoneme_3F989843-4181-4B61-B4C6-7DD7A66D8CC3.wav
# Processed and saved transcription for: testPhoneme_F781D0D4-D0BB-4C9B-BDB7-5DC5AF5997AE.wav
# Processed and saved transcription for: testPhoneme_A175CEB0-7DD7-42A7-9362-0F1135ED12F8.wav
# Processed and saved transcription for: testPhoneme_8718E568-2D18-4C20-980A-880CFDC89139.wav
# Processed and saved transcription for: testPhoneme_4E1C71F4-B1A9-460E-A6C5-3BBB610796E5.wav
# Processed and saved transcription for: testPhoneme_55043D45-245F-4FAF-BE31-4879BCFA848E.wav
# Processed and saved transcription for: testPhoneme_21F342B4-2288-4CDE-A502-B7164D1B65A9.wav
# Processed and saved transcription for: testPhoneme_5DC5D751-07EA-46D7-85D4-FBD28F326C69.wav
# Processed and saved transcription for: testPhoneme_2FF8CA32-A5FC-4419-8842-6AC3F1116D8C.wav
# Processed and saved transcription for: testPhoneme_43217C92-CB37-462D-B619-A75882C5168E.wav
# Processed and saved transcription for: testPhoneme_0A6C7473-5EE1-40CA-AC6F-F7C6534EFEF8.wav
# Processed and saved transcription for: testPhoneme_BAADB55D-D646-43FD-8C1E-D1F2D6961459.wav
# Processed and saved transcription for: testPhoneme_AD51DE7C-EC39-4298-A0E9-47A1D80454B5.wav
# Processed and saved transcription for: testPhoneme_11CB9212-F7BE-44D7-BDB3-D85D75B86A67.wav
# Processed and saved transcription for: testPhoneme_68615A5A-005F-4A4A-8D8A-52CFEF837F6C.wav
# Processed and saved transcription for: testPhoneme_A70837C9-BCBC-411E-90A1-C7F36F8F5475.wav
# Processed and saved transcription for: testPhoneme_80F2DF66-3752-472C-97BC-D52758D7B3D6.wav
# Processed and saved transcription for: testPhoneme_8C55CF39-BD67-4820-9C41-2966D5EEE3BF.wav
# Processed and saved transcription for: testPhoneme_FC0830C6-4C3E-4423-BF64-13F385F0D6F2.wav
# Processed and saved transcription for: testPhoneme_D7125667-FBBC-4F72-ABB0-2C5B3D66B0E1.wav
# Processed and saved transcription for: testPhoneme_F3FAD40C-EB3A-4243-8DF4-D76A9B11EAC0.wav
# Processed and saved transcription for: testPhoneme_8791C552-8243-4298-B89D-3046498D3DE1.wav
# Processed and saved transcription for: testPhoneme_549CB1EB-53B0-4C36-99E4-3588B00F0B2B.wav
# Processed and saved transcription for: testPhoneme_53AF246F-2C9F-48AE-B3B2-44A8729819DE.wav
# Processed and saved transcription for: testPhoneme_3C1F481F-4F88-42A8-81B5-5D2365A61F39.wav
# Processed and saved transcription for: testPhoneme_D2043AB4-8067-477D-AC40-53F8EDE19665.wav
# Processed and saved transcription for: testPhoneme_CE0B572E-3A5B-437B-8293-656A978E5CF0.wav
# Processed and saved transcription for: testPhoneme_DD884C44-FEC0-4832-8A90-F0C79474FC4A.wav
# Processed and saved transcription for: testPhoneme_4075E6FB-C063-46CF-94F7-554618EF0A88.wav
# Processed and saved transcription for: testPhoneme_B36EF882-3656-48F3-B701-4FA137B61010.wav
# Processed and saved transcription for: testPhoneme_FCF52C26-BD9C-46EB-9AB8-BDF501AD971D.wav
# Processed and saved transcription for: testPhoneme_971CBF1F-52E4-4007-BDD8-851CEBF4F9EB.wav
# Processed and saved transcription for: testPhoneme_D428D15C-C60A-4C47-BAE1-D5F0DD4099D7.wav
# Processed and saved transcription for: testPhoneme_B4351B27-EF2D-4251-9FD7-E584801144DE.wav
# Processed and saved transcription for: testPhoneme_9EF19434-0FBA-4041-B33A-7B1A5772D9A4.wav
# Processed and saved transcription for: testPhoneme_4A297266-5875-4BEB-8600-7C08176D7000.wav
# Processed and saved transcription for: testPhoneme_0A3DB196-2280-49E8-A3A2-B82483FF3233.wav
# Processed and saved transcription for: testPhoneme_BDC4F14C-77E5-465F-A2D1-64A87D9C2973.wav
# Processed and saved transcription for: testPhoneme_4C5AB353-77B9-4D7A-B974-20389D4A4CD5.wav
# Processed and saved transcription for: testPhoneme_29292656-FA59-43C2-B243-ACEE9EE0A679.wav
# Processed and saved transcription for: testPhoneme_A8F46369-5F13-4D91-9A31-C43E37B3216C.wav
# Processed and saved transcription for: testPhoneme_2F558A1B-2C70-478B-A052-63DB5F7ACED5.wav
# Processed and saved transcription for: testPhoneme_0D578070-850C-4A0A-98CD-3BF895621800.wav
# Processed and saved transcription for: testPhoneme_A2DA3F43-DBF9-47BB-A2C0-EC6220D0B2FD.wav
# Processed and saved transcription for: testPhoneme_D530C0E8-BCC1-4AF7-B8D7-222B98EF4617.wav
# Processed and saved transcription for: testPhoneme_78619091-6FAA-4329-9ADC-211F242E2C51.wav
# Processed and saved transcription for: testPhoneme_DB6EDC48-040A-48EF-BCD8-9234822A3E82.wav
# Processed and saved transcription for: testPhoneme_59A6850F-CF62-4BA0-84BB-D965511EFC59.wav
# Processed and saved transcription for: testPhoneme_3188517D-1494-4C43-A226-4356CCC8B4BA.wav
# Processed and saved transcription for: testPhoneme_F5FE41D5-7274-495D-AE90-33A9FF7A8409.wav
# Processed and saved transcription for: testPhoneme_438DE339-68EB-47BB-8C52-2DDDD1C2C9C4.wav
# Processed and saved transcription for: testPhoneme_D987E1D8-D53F-475B-8B87-19C42FBDE89C.wav
# Processed and saved transcription for: testPhoneme_01C4B1E9-48E2-4CD2-BBC9-C547EB97D754.wav
# Processed and saved transcription for: testPhoneme_F3A41388-9FB4-438A-B3B0-5D9B447CFD2E.wav
# Processed and saved transcription for: testPhoneme_BE5F9318-5C25-41A9-9AD4-BF9CD316FE45.wav
# Processed and saved transcription for: testPhoneme_A932211C-FEA4-49D1-BB0D-C3E24D9D5131.wav
# Processed and saved transcription for: testPhoneme_A4366250-DE73-424D-A2D2-E66F1D03E617.wav
# Processed and saved transcription for: testPhoneme_EF02C95B-D7A7-44D2-A6B1-D24389F8AC73.wav
# Processed and saved transcription for: testPhoneme_A7504C57-2470-4575-9AA9-4DAEF5711F8E.wav
# Processed and saved transcription for: testPhoneme_8A727125-C742-4259-9CC0-0AD432E4A4BF.wav
# Processed and saved transcription for: testPhoneme_19844685-58CC-49CA-B5A6-3F434624108C.wav
# Processed and saved transcription for: testPhoneme_F10C3ABE-549B-41AC-89E7-B5F581531F4C.wav
# Processed and saved transcription for: testPhoneme_8BDDB598-8C9B-4561-8CF3-D9ED636A96BA.wav
# Processed and saved transcription for: testPhoneme_E632B118-CFEB-4138-8784-D4C8E49ADA7C.wav
# Processed and saved transcription for: testPhoneme_DB886862-57F0-4834-B9A5-856DFDBADAA7.wav
# Processed and saved transcription for: testPhoneme_8A827857-FEFD-476D-A3B3-9AB0DF3F0A86.wav
# Processed and saved transcription for: testPhoneme_6ED9E989-53F4-4F2C-BC87-AE22BA60676C.wav
# Processed and saved transcription for: testPhoneme_C0186AB4-9D6B-44F1-A10B-8FFC4FD01EC2.wav
# Processed and saved transcription for: testPhoneme_B4564E3B-F139-485C-8DB0-45F55681BBE2.wav
# Processed and saved transcription for: testPhoneme_A2FAE233-3901-48E7-86B0-E392872E891A.wav
# Processed and saved transcription for: testPhoneme_A60C2B63-A0DF-447C-9A11-F17E72595C95.wav
# Processed and saved transcription for: testPhoneme_783EFB4F-1E19-4FF0-BE1F-6274A9B3EF5C.wav
# Processed and saved transcription for: testPhoneme_643DAF81-575B-4641-B679-2F8FBF2133EE.wav
# Processed and saved transcription for: testPhoneme_6B55AF10-CD73-4FC1-90C2-73B6970FD910.wav
# Processed and saved transcription for: testPhoneme_D955B474-0FAA-4490-9026-7B356916E059.wav
# Processed and saved transcription for: testPhoneme_C989F901-2EEA-4FE0-AFC6-9B3C30280276.wav
# Processed and saved transcription for: testPhoneme_207BF9D7-BB60-46D7-BDB7-212006C8A139.wav
# Processed and saved transcription for: testPhoneme_555ECA12-3982-4FB5-B44B-CFDBD39901A0.wav
# Processed and saved transcription for: testPhoneme_D1F3944A-6DCD-4B79-960D-7F8E054B8D7A.wav
# Processed and saved transcription for: testPhoneme_E2AEEB53-20F0-4403-85CC-21CDC5EC3B22.wav
# Processed and saved transcription for: testPhoneme_4D9FDEB2-381E-476A-B25A-0192F6D24DDF.wav
# Processed and saved transcription for: testPhoneme_967FB1B2-FFA0-4790-A21F-01190C962786.wav
# Processed and saved transcription for: testPhoneme_55872796-A1AD-41FD-8E3E-0388CF109B7A.wav
# Processed and saved transcription for: testPhoneme_1BE02E59-DFAE-4322-BF2E-210524898FD9.wav
# Processed and saved transcription for: testPhoneme_E201B037-51A4-4D2D-B62C-97B78AC9AA55.wav
# Processed and saved transcription for: testPhoneme_D3C32716-C335-4501-B642-EC6F1D2F262F.wav
# Processed and saved transcription for: testPhoneme_23AAC953-2732-4B66-9116-441BDDC467D9.wav
# Processed and saved transcription for: testPhoneme_7A81848C-A424-4BBB-99C3-19F2F76A3866.wav
# Processed and saved transcription for: testPhoneme_7397702D-F6C2-49F3-BEC1-5C6251710F77.wav
# Processed and saved transcription for: testPhoneme_EE3A0A30-D8A5-4390-97E4-E1392399B9F7.wav
# Processed and saved transcription for: testPhoneme_643535E9-EEBB-41B8-977F-4F7DA12B956B.wav
# Processed and saved transcription for: testPhoneme_B8C133A1-9B32-44BE-A448-9F6C808ACCF0.wav
# Processed and saved transcription for: testPhoneme_533DD309-889B-49C4-A38B-351AD8ED5934.wav
# Processed and saved transcription for: testPhoneme_700E7C9E-2F28-4287-8635-654341515621.wav
# Processed and saved transcription for: testPhoneme_1BC5460E-AE24-4667-83DC-AF66A3B907C6.wav
# Processed and saved transcription for: testPhoneme_30BCECA2-8F75-4CAE-A1B3-A63148291E63.wav
# Processed and saved transcription for: testPhoneme_E2D7445F-C2C8-49AD-B421-266A560099A6.wav
# Processed and saved transcription for: testPhoneme_CB54EE9A-4497-46AE-8566-DEEE121B2442.wav
# Processed and saved transcription for: testPhoneme_7EB9E312-0E9E-4346-AD99-70F3BAE0D186.wav
# Processed and saved transcription for: testPhoneme_759432CA-6FBF-4BCE-A7A3-09683559B88C.wav
# Processed and saved transcription for: testPhoneme_1A2EBD01-E868-4E0F-9F40-4965BB53B6C9.wav
# Processed and saved transcription for: testPhoneme_D3399169-970E-4D77-BEA8-555F52F35F66.wav
# Processed and saved transcription for: testPhoneme_5AF384E4-7D72-4E83-92FB-8060ED70ED52.wav
# Processed and saved transcription for: testPhoneme_4806B4B6-2B79-4B15-8446-05615D87338F.wav
# Processed and saved transcription for: testPhoneme_18C112F8-8C1F-441B-B528-6244093F22BA.wav
# Processed and saved transcription for: testPhoneme_E1A238A5-7E73-4FE9-9986-4A14B017E2A0.wav
# Processed and saved transcription for: testPhoneme_ABA6EE4C-512C-48C8-A05D-E93A7637EEC7.wav
# Processed and saved transcription for: testPhoneme_969F7343-1415-4F06-96B0-CFCCC32D7D3E.wav
# Processed and saved transcription for: testPhoneme_3160C2C8-44FA-49B4-9BCE-2FF6EAF0674B.wav
# Processed and saved transcription for: testPhoneme_ED00301C-8629-421B-8E8D-FD3B137B6C61.wav
# Processed and saved transcription for: testPhoneme_DAF13A7E-64A2-4F55-8E92-687AD296518B.wav
# Processed and saved transcription for: testPhoneme_E83A913C-9E30-48D3-A1FD-A79F213055ED.wav
# Processed and saved transcription for: testPhoneme_31D455DE-7D07-4895-B172-25F32BEC7692.wav
# Processed and saved transcription for: testPhoneme_4BF84359-401C-4E7E-B972-E07DCD53A2CD.wav
# Processed and saved transcription for: testPhoneme_E22FF28E-D391-4C8C-8812-7E1A15F8C93E.wav
# Processed and saved transcription for: testPhoneme_2197E2CF-3A6B-40AE-BA66-39B8EE3E7097.wav
# Processed and saved transcription for: testPhoneme_1B2491CF-D3BB-491F-9A0A-D5F2E0DD5BA3.wav
# Processed and saved transcription for: testPhoneme_CA66EE00-6D0D-4FDE-8CF7-48310CD826BA.wav
# Processed and saved transcription for: testPhoneme_1EFA2F89-0580-49EC-BC39-72EDE63F5920.wav
# Processed and saved transcription for: testPhoneme_6D7D5F41-5512-4CC0-BF2F-1C6FA008BD34.wav
# Processed and saved transcription for: testPhoneme_6FF731A6-DD89-432E-B690-DF9A3B76C86D.wav
# Processed and saved transcription for: testPhoneme_81F4D3BB-1498-4EC0-A49A-7BFE0D277542.wav
# Processed and saved transcription for: testPhoneme_FA95D264-E325-43E7-94C7-A331E50B5112.wav
# Processed and saved transcription for: testPhoneme_843FB29A-1892-457E-9F97-879EE78D132F.wav
# Processed and saved transcription for: testPhoneme_3103FD5D-FCA5-4DB7-8D32-4EA796FC3BEA.wav
# Processed and saved transcription for: testPhoneme_3FCB7B71-0856-49F5-A67C-C9C5538FFDEF.wav
# Processed and saved transcription for: testPhoneme_1E0ED052-0984-4990-9F1C-62710538EE39.wav
# Processed and saved transcription for: testPhoneme_F29D9B27-1FAB-4CEA-8E8F-CA9940105A34.wav
# Processed and saved transcription for: testPhoneme_A1979E53-DF69-434E-8E33-B68EC1F8B045.wav
# Processed and saved transcription for: testPhoneme_7BA6BFEE-D11D-4740-9A58-BD80FC029CD6.wav
# Processed and saved transcription for: testPhoneme_A5F708CC-F67F-4115-9678-2F009FA42028.wav
# Processed and saved transcription for: testPhoneme_7B959C5B-DA4C-44B0-97B9-3773A3ABF2E2.wav
# Processed and saved transcription for: testPhoneme_A5467D11-BD59-4B92-B950-52A7C8620247.wav
# Processed and saved transcription for: testPhoneme_5D934150-4530-4B38-B3DC-2E625ACE20B9.wav
# Processed and saved transcription for: testPhoneme_52B3A7D6-05CF-4A1B-B66C-50FB16E3728F.wav
# Processed and saved transcription for: testPhoneme_F297AB89-C861-4DFD-B5E2-8B9D951AF331.wav
# Processed and saved transcription for: testPhoneme_2B29D9FD-9333-44C5-A065-BEBFCBDB816B.wav
# Processed and saved transcription for: testPhoneme_8AA5E45F-739F-4B4A-8F77-062027B56ED9.wav
# Processed and saved transcription for: testPhoneme_D83B8E46-8BDC-4583-A209-698055306DDA.wav
# Processed and saved transcription for: testPhoneme_465B90E2-0BA6-458A-B02B-2D8962C28138.wav
# Processed and saved transcription for: testPhoneme_0928CE7F-8F25-4329-8A64-13C1E49068BB.wav
# Processed and saved transcription for: testPhoneme_8E62F425-AAC3-471B-9B99-C35E5B950F72.wav
# Processed and saved transcription for: testPhoneme_8CF5C752-AB34-479F-A671-9844FB0AD70E.wav
# Processed and saved transcription for: testPhoneme_9834EC85-1112-421B-A225-899C959AABBF.wav
# Processed and saved transcription for: testPhoneme_81995B6D-C163-4020-A179-69782A6D096F.wav
# Processed and saved transcription for: testPhoneme_33A73601-3CCF-41FE-A22E-7D4C94B422A0.wav
# Processed and saved transcription for: testPhoneme_6DD1A800-EA3E-452B-A21E-93A06EB5C5B0.wav
# Processed and saved transcription for: testPhoneme_C9A67D9C-A7A9-4B0C-A1D5-34BD30876F4D.wav
# Processed and saved transcription for: testPhoneme_C33C352D-D4AD-4FD6-8C21-9E0B90B3D039.wav
# Processed and saved transcription for: testPhoneme_CB6C3CDA-6923-46EA-B387-3C3261601B20.wav
# Processed and saved transcription for: testPhoneme_A7BD890E-FC84-4ED1-83DB-87152FD4C18D.wav
# Processed and saved transcription for: testPhoneme_033A8A3A-8769-48E8-977A-CE1004D88357.wav
# Processed and saved transcription for: testPhoneme_E9CAD35C-646D-4075-81F4-E44E0A869D59.wav
# Processed and saved transcription for: testPhoneme_9E19FBAD-6752-42A1-BE2B-5EC16DD68452.wav
# Processed and saved transcription for: testPhoneme_9390FECE-38B0-4634-961F-4A06A3787562.wav
# Processed and saved transcription for: testPhoneme_2A530D35-3AF4-4AC2-A072-F82F5447787B.wav
# Processed and saved transcription for: testPhoneme_EE2D20E7-A853-4F34-B775-0EB10239BA46.wav
# Processed and saved transcription for: testPhoneme_F28F377A-6900-423E-A245-92B66531C7DA.wav
# Processed and saved transcription for: testPhoneme_33F6CDF2-0D3B-4104-B59D-2442B0CA6729.wav
# Processed and saved transcription for: testPhoneme_1C3FDC14-E820-4085-AE21-2B3F3FA547A2.wav
# Processed and saved transcription for: testPhoneme_928021ED-1A96-4BDF-904B-3B9ADE7A0F78.wav
# Processed and saved transcription for: testPhoneme_6A60B767-EC3C-413A-9C52-EB5AEA2D240F.wav
# Processed and saved transcription for: testPhoneme_22EA1E4C-C5B5-4898-B037-B9290271E9DA.wav
# Processed and saved transcription for: testPhoneme_E5AA7494-E88D-4DE8-AAE7-8347DA435082.wav
# Processed and saved transcription for: testPhoneme_45E377BA-FF38-44C0-8FDD-D0B622F85C06.wav
# Processed and saved transcription for: testPhoneme_A7C493B3-6E95-48F1-A2CD-14521BFC3D94.wav
# Processed and saved transcription for: testPhoneme_A5D0AA07-E4E4-4771-880A-FB295DDDA1E1.wav
# Processed and saved transcription for: testPhoneme_8ED35EDF-AB79-4F6C-BC97-86ACC24213B0.wav
# Processed and saved transcription for: testPhoneme_88AF3834-0D14-4099-AC49-24A8DB169AC2.wav
# Processed and saved transcription for: testPhoneme_7E950F22-10AD-4823-BE3F-56A9A36DEFF4.wav
# Processed and saved transcription for: testPhoneme_B963CDA0-EF99-43BB-AFA0-A0373AD22104.wav
# Processed and saved transcription for: testPhoneme_83012B7F-766C-4D37-BF66-223184170CA8.wav
# Processed and saved transcription for: testPhoneme_5B0FC044-3184-4277-B39D-4584917A9BF5.wav
# Processed and saved transcription for: testPhoneme_EAE9CEDD-649B-4CD7-B0DC-2C10348E8520.wav
# Processed and saved transcription for: testPhoneme_F67D8291-4836-4321-8111-E95A70FEE0C3.wav
# Processed and saved transcription for: testPhoneme_0BFC7BC6-0FCE-4A2C-8AD0-158C18D021B3.wav
# Processed and saved transcription for: testPhoneme_7DDDCC2C-6F80-4FBE-B0AD-9A8FA91CED27.wav
# Processed and saved transcription for: testPhoneme_8A93060C-4712-4157-BFD8-61AA96FC4E78.wav
# Processed and saved transcription for: testPhoneme_B65FF9E2-DF57-40A4-9B7A-EFDC4FD540DF.wav
# Processed and saved transcription for: testPhoneme_CEED814B-6A55-45E8-A395-74B4E512EC13.wav
# Processed and saved transcription for: testPhoneme_BB736DA4-C3C5-4CCF-963D-9A237C62E556.wav
# Processed and saved transcription for: testPhoneme_40C1A851-214D-4960-B072-C64D52A6E4F6.wav
# Processed and saved transcription for: testPhoneme_6DC11E97-0D8B-41FD-918F-FAAA99FE35CA.wav
# Processed and saved transcription for: testPhoneme_137B9A2E-5F06-44F8-B9A7-8F4EE043517C.wav
# Processed and saved transcription for: testPhoneme_B4C585FC-2DFD-496B-9E4B-AD48EB096DAE.wav
# Processed and saved transcription for: testPhoneme_48737298-E14A-4A7F-89BF-7F0F7A0EAE6C.wav
# Processed and saved transcription for: testPhoneme_B901A54C-7F69-4E52-BC65-3AFF7DE5BA92.wav
# Processed and saved transcription for: testPhoneme_2474CB34-0596-4AEF-93A2-452816DE7E1F.wav
# Processed and saved transcription for: testPhoneme_D232CF0A-BF2F-468B-B098-55B5E5D9FCCA.wav
# Processed and saved transcription for: testPhoneme_D025A21C-C9B0-4175-BD55-4A634C4834AB.wav
# Processed and saved transcription for: testPhoneme_14E3F5F7-415F-43EB-839D-E900B539BCCB.wav
# Processed and saved transcription for: testPhoneme_6E716A75-42AF-469A-9CE6-043AD22FE99F.wav
# Processed and saved transcription for: testPhoneme_DE86EEBB-18C0-4519-8B2F-33A8B652C7D0.wav
# Processed and saved transcription for: testPhoneme_6ECEF539-52F0-452F-BEBE-A4A7EB35ADA4.wav
# Processed and saved transcription for: testPhoneme_2A8CB8E7-3D9E-46CF-BC42-78BBD70573E8.wav
# Processed and saved transcription for: testPhoneme_46CA286B-17E6-45EB-9CBA-9876FC0A660A.wav
# Processed and saved transcription for: testPhoneme_C78E819C-7E38-4A6F-A3D0-476F3C82AC11.wav
# Processed and saved transcription for: testPhoneme_033021B4-1D06-45B4-A37D-36FF0D1A6819.wav
# Processed and saved transcription for: testPhoneme_73EE94F4-43CB-4E2E-83F6-A2F1E1346DC7.wav
# Processed and saved transcription for: testPhoneme_32B791A5-3D79-4283-83F3-40D3690B8C42.wav
# Processed and saved transcription for: testPhoneme_C1E06601-DE73-4F43-8CBB-CF98357C600B.wav
# Processed and saved transcription for: testPhoneme_68E394CA-B292-4F2F-B855-81B0BEA89D22.wav
# Processed and saved transcription for: testPhoneme_2718B00C-4634-48FC-8D49-C97407BEE4AB.wav
# Processed and saved transcription for: testPhoneme_65A05AFD-333A-4937-8C22-836A45685966.wav
# Processed and saved transcription for: testPhoneme_7688CF0A-8DEC-4DA4-8C6F-C71C303424B4.wav
# Processed and saved transcription for: testPhoneme_36FC56DE-8BD0-495B-BB8D-00E54920482C.wav
# Processed and saved transcription for: testPhoneme_491E6613-A873-415B-B919-B147B9030575.wav
# Processed and saved transcription for: testPhoneme_F2119C45-CC8E-44ED-A943-424A630FD007.wav
# Processed and saved transcription for: testPhoneme_679CC6AC-884D-44ED-B9B2-4C7757AF285E.wav
# Processed and saved transcription for: testPhoneme_CD417AE5-D097-49B1-B43D-6868F75D3EA4.wav
# Processed and saved transcription for: testPhoneme_03EA13E9-22E4-4999-A03A-F1BF198DC39A.wav
# Processed and saved transcription for: testPhoneme_280D5B90-9C79-4522-93C8-B0855C452883.wav
# Processed and saved transcription for: testPhoneme_3DA39070-058E-43D8-8A55-A37E8C55A8CB.wav
# Processed and saved transcription for: testPhoneme_CDE6FF70-0324-4D09-A741-16D13DF459C7.wav
# Processed and saved transcription for: testPhoneme_C4E173C6-41F1-4DC9-9882-935DC2C223D6.wav
# Processed and saved transcription for: testPhoneme_D490E37B-2CF8-4D5C-B2E7-5D65F8EA0B43.wav
# Processed and saved transcription for: testPhoneme_980FD28C-FE91-46CB-8AC1-0EF338126D90.wav
# Processed and saved transcription for: testPhoneme_4AED46C6-7284-4C98-92AD-0281D1D9E72D.wav
# Processed and saved transcription for: testPhoneme_E21A3E8A-67E0-441E-8F9A-BD01E3787F57.wav
# Processed and saved transcription for: testPhoneme_9E53821B-BCB8-4F11-9373-721C18DCA23F.wav
# Processed and saved transcription for: testPhoneme_41874E3D-CFB7-4498-AE76-5C91F5C96193.wav
# Processed and saved transcription for: testPhoneme_052F6BF3-5DE4-4EA4-8509-7133664C769E.wav
# Processed and saved transcription for: testPhoneme_F678DC6C-5CFC-4A6D-9602-A27E9FE1D901.wav
# Processed and saved transcription for: testPhoneme_4E813B51-752E-4026-8A46-5B11F67824B6.wav
# Processed and saved transcription for: testPhoneme_B8B72367-089C-43C0-B376-55122A8F5BEB.wav
# Processed and saved transcription for: testPhoneme_AFF0F1CB-CC07-416A-B70D-8435AD6B5751.wav
# Processed and saved transcription for: testPhoneme_FB42AA72-0A64-4178-895E-3EA96F83F616.wav
# Processed and saved transcription for: testPhoneme_267D2356-14A6-462B-86D0-47DD18E4F879.wav
# Processed and saved transcription for: testPhoneme_DC90FB39-C99F-4B6C-B717-44E5BD0508D6.wav
# Processed and saved transcription for: testPhoneme_99CB6B0C-EC09-446B-A35F-1B02923A9089.wav
# Processed and saved transcription for: testPhoneme_CAB9BAD5-8F4E-42C4-8DB5-B761911BC8C3.wav
# Processed and saved transcription for: testPhoneme_1514A0F0-2350-49F5-A5E6-0F01DECE2C06.wav
# Processed and saved transcription for: testPhoneme_3B507B98-CB2D-47D3-8DD5-5986FD9E2A11.wav
# Processed and saved transcription for: testPhoneme_B34C24B2-998D-40D2-8DB3-A74FD633FEAB.wav
# Processed and saved transcription for: testPhoneme_C74A5B3B-0B8B-4E9E-A2C6-8AE2F6376EE4.wav
# Processed and saved transcription for: testPhoneme_693B2016-5B9A-4917-B2EC-55F2C4E5CA8E.wav
# Processed and saved transcription for: testPhoneme_96A10AE3-7D8F-480F-8DCE-4E5924437390.wav
# Processed and saved transcription for: testPhoneme_FFB4D3EA-4AEA-4FB9-B9E7-04E6F39785AE.wav
# Processed and saved transcription for: testPhoneme_64BFEF32-4875-4529-A617-50A928064AE3.wav
# Processed and saved transcription for: testPhoneme_98D43F49-B241-4561-9DD8-64A4476D8D00.wav
# Processed and saved transcription for: testPhoneme_2F4F389F-B61E-45FE-A5DC-9518D4431C4C.wav
# Processed and saved transcription for: testPhoneme_09CF304F-0000-4042-962D-2A785C2DCCF1.wav
# Processed and saved transcription for: testPhoneme_BAC46758-8E60-42ED-8699-1684BE5F92BA.wav
# Processed and saved transcription for: testPhoneme_94FA58B1-5D90-401B-8F1A-B14D0DE7D930.wav
# Processed and saved transcription for: testPhoneme_EE999765-6203-425B-B127-6221849FEC13.wav
# Processed and saved transcription for: testPhoneme_DBF78E1B-53A1-4114-A21F-1A96F2E70173.wav
# Processed and saved transcription for: testPhoneme_94D142E3-8A59-44DA-B01A-533D662478C7.wav
# Processed and saved transcription for: testPhoneme_BE950DBA-7581-4FF0-8732-C261749CD253.wav
# Processed and saved transcription for: testPhoneme_6451A088-BC94-451C-877B-22D835255226.wav
# Processed and saved transcription for: testPhoneme_63858189-93FE-4AC8-B1AB-928271431D9F.wav
# Processed and saved transcription for: testPhoneme_6F0A679B-88FC-4D3A-A8C5-5EF95CE45383.wav
# Processed and saved transcription for: testPhoneme_2001C59B-C404-492A-AF54-A881EEAABFBB.wav
# Processed and saved transcription for: testPhoneme_8B471CFF-2794-4C27-B75D-B60829AC47B4.wav
# Processed and saved transcription for: testPhoneme_2AEE17B8-8F96-48CF-8D6A-82E809509590.wav
# Processed and saved transcription for: testPhoneme_F5E0BA46-37BD-4448-A1E0-37F7A1E9CD8E.wav
# Processed and saved transcription for: testPhoneme_2E9818A2-7153-47F5-A048-79E916CFF32A.wav
# Processed and saved transcription for: testPhoneme_DEE0640F-D249-4AEA-A801-CCA731025EA0.wav
# Processed and saved transcription for: testPhoneme_3079315A-8BA1-4735-89F1-2B2803227B86.wav
# Processed and saved transcription for: testPhoneme_F8882B59-CCC1-46CC-84B1-0184AB8BE7CA.wav
# Processed and saved transcription for: testPhoneme_82412FAD-B077-49A9-B5D3-CE8FE3346D58.wav
# Processed and saved transcription for: testPhoneme_0D8083E3-E40B-4ABE-BBB8-453A2EA8AFA5.wav
# Processed and saved transcription for: testPhoneme_79DD1FC7-AC56-48E0-AEE3-0F26CE14CC24.wav
# Processed and saved transcription for: testPhoneme_3C52A497-3143-4C4F-ADCD-112E845D532C.wav
# Processed and saved transcription for: testPhoneme_A0D72D4E-BC51-42B8-A649-7A632384BB42.wav
# Processed and saved transcription for: testPhoneme_2286EE2E-8006-4B07-9B6A-D463E677DDBD.wav
# Processed and saved transcription for: testPhoneme_2968E293-EF03-4558-B3C6-DA56E7C01245.wav
# Processed and saved transcription for: testPhoneme_CD59A88D-4498-46CD-A05F-3875EBBAA9DA.wav
# Processed and saved transcription for: testPhoneme_58BC0EDD-8C9C-46FC-B75D-7BAEBB551AF8.wav
# Processed and saved transcription for: testPhoneme_E1CBF84E-3E4C-46DD-842B-FEBF1E888DDD.wav
# Processed and saved transcription for: testPhoneme_74B39D5F-1266-4641-B4A0-3E55A39CB206.wav
# Processed and saved transcription for: testPhoneme_0AFAE87B-591F-4532-A472-1613DF2207D2.wav
# Processed and saved transcription for: testPhoneme_A232A7F3-3608-4C21-BF44-2ABB7F67DEEE.wav
